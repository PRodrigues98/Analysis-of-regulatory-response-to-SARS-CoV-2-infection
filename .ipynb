# %% [markdown]
# # Clustering

# %%
import dataInterpreter as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster
from sklearn.preprocessing import StandardScaler

dt.get_data('NHBE', 'sars-cov2')
# Out:
#            Series1_NHBE_SARS-CoV-2_1  Series1_NHBE_SARS-CoV-2_2  \
# DDX11L1                     0.000000                   0.000000
# WASH7P                      3.555348                   2.995732
# FAM138A                     0.000000                   0.000000
# FAM138F                     0.000000                   0.000000
# OR4F5                       0.000000                   0.000000
# ...                              ...                        ...
# CDY1B                       0.000000                   0.000000
# CDY1                        0.000000                   0.000000
# CSPG4P1Y                    0.000000                   0.000000
# GOLGA2P3Y                   0.000000                   0.000000
# GOLGA2P2Y                   0.000000                   0.000000
#
#            Series1_NHBE_SARS-CoV-2_3
# DDX11L1                     0.000000
# WASH7P                      3.806662
# FAM138A                     0.000000
# FAM138F                     0.000000
# ...

# %%
NHBE_data_healthy = dt.get_data('NHBE', 'healthy')
NHBE_data_infected = dt.get_data('NHBE', 'sars-cov2')

NHBE_data = pd.concat([NHBE_data_healthy, NHBE_data_infected], axis = 1)

NHBE_normalized_data = pd.DataFrame(data = StandardScaler().fit_transform(NHBE_data.T), columns = NHBE_data.index).T
NHBE_normalized_data
# Out:
#                   0         1         2         3        4         5        6  \
# DDX11L1    0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# WASH7P    -0.602829 -0.999516 -1.088335  0.831526  0.86872  0.676049  1.78748
# FAM138A    0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# FAM138F    0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# OR4F5      0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# ...             ...       ...       ...       ...      ...       ...      ...
# CDY1B      0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# CDY1       0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# CSPG4P1Y   0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# GOLGA2P3Y  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
# GOLGA2P2Y  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000
#
# ...

# %%
two_means = cluster.MiniBatchKMeans(n_clusters=20)
two_means.fit(NHBE_normalized_data)

len(two_means.labels_)
# Out:
# 21797

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

range_n_clusters = [int(21797 / i) for i in range(2, 50)]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(NHBE_normalized_data) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = clusterer.fit_predict(NHBE_normalized_data)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(NHBE_normalized_data, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(NHBE_normalized_data, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 10898 The average silhouette_score is : 0.3325125665877833
# For n_clusters = 7265 The average silhouette_score is : 0.3472579664736602
# For n_clusters = 5449 The average silhouette_score is : 0.35156646672670894
# For n_clusters = 4359 The average silhouette_score is : 0.35260204165023623
# For n_clusters = 3632 The average silhouette_score is : 0.35335695833453734
# For n_clusters = 3113 The average silhouette_score is : 0.35284771852062385
# For n_clusters = 2724 The average silhouette_score is : 0.35193829985321956
# For n_clusters = 2421 The average silhouette_score is : 0.3521267087237366
# For n_clusters = 2179 The average silhouette_score is : 0.3508344166577838
# For n_clusters = 1981 The average silhouette_score is : 0.35029403255835173
# For n_clusters = 1816 The average silhouette_score is : 0.349444798985218
# For n_clusters = 1676 The average silhouette_score is : 0.3470911114301119
# ...
