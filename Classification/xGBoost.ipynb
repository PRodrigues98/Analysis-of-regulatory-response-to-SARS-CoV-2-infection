# %%
import sys
sys.path.append("../")

import dataInterpreter as dt
import enrichmentAnalysis as ea
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
pd.options.mode.chained_assignment = None  # default='warn'

import xgboost as xgb
from sklearn.metrics import mean_squared_error

path = "C:\\Users\\Pedro\\Documents\\BicPAMS\\bicpams_5.1\\data\\latecovid\\"

# %%
filtered_data_01 = pd.read_csv(path + 'data-p01.csv', index_col = 0, sep = '\t').T
filtered_data_05 = pd.read_csv(path + 'data-p05.csv', index_col = 0, sep = '\t').T

# %%
classes = {'NHBE': {}, 'A549': {}, 'Calu3': {}, 'Biopsy': {}}
i = 0
for c in filtered_data_01.index:
    info = dt.get_info_from_name(c)
    if info['Condition'] not in classes[info['Cell Type']]:
        classes[info['Cell Type']][info['Condition']] = i
        i += 1
        
y = []
for c in filtered_data_01.index:
    info = dt.get_info_from_name(c)
    y.append(classes[info['Cell Type']][info['Condition']])
    
y_names = [' '] * 13
for c_type in classes:
    for cond in classes[c_type]:
        y_names[classes[c_type][cond]] = c_type + ' ' + cond

# %%
parameters = {
    'seed': 42, 
    'use_label_encoder': False,
    'booster': 'gbtree',
    'eta': 0.3,
    'gamma': 0,
    'alpha': 0,
    'n_estimators': 400,
    'eval_metric': 'mlogloss'
}

stats = dt.apply_loocv(filtered_data_01.values, np.array(y), xgb.XGBClassifier(**parameters))
stats
# Out:
# {'accuracy': 0.8333333333333334,
#  'importances': array([1.51567477e-02, 1.87414878e-03, 2.25780616e-04, 1.53541223e-02,
#         1.07414615e-03, 8.30417431e-03, 1.03555782e-03, 9.25054644e-03,
#         2.27620066e-05, 2.35013421e-03, 3.03968835e-05, 3.90527527e-03,
#         1.69028337e-02, 1.14295912e-03, 7.40122368e-02, 4.49351856e-04,
#         2.07753115e-04, 7.52164859e-04, 2.17970493e-03, 1.02165082e-03,
#         2.08289449e-04, 7.29739627e-04, 1.95741645e-02, 2.88464549e-03,
#         0.00000000e+00, 1.92097387e-03, 1.28293403e-06, 1.17236435e-03,
#         3.48453163e-04, 2.28825638e-04, 6.84369476e-03, 0.00000000e+00,
#         2.59701949e-04, 2.11082198e-03, 9.35280095e-03, 0.00000000e+00,
#         1.12821759e-05, 6.25204036e-04, 1.77100986e-04, 3.07144733e-03,
#         1.88006312e-04, 1.69814823e-04, 9.93971402e-04, 4.14471061e-02,
#         0.00000000e+00, 4.96382590e-06, 8.79292670e-04, 0.00000000e+00,
#         2.55225588e-05, 9.36857860e-04, 0.00000000e+00, 1.93885027e-04,
#         1.72924349e-03, 2.12553161e-04, 0.00000000e+00, 8.86870341e-04,
#         2.19158777e-04, 4.38203871e-05, 4.43834536e-05, 9.98645426e-04,
#         4.37675044e-06, 0.00000000e+00, 2.50330648e-05, 6.12690950e-05,
#         0.00000000e+00, 2.06545012e-04, 3.55479467e-05, 0.00000000e+00,
#         0.00000000e+00, 1.50869250e-03, 7.26936614e-05, 0.00000000e+00,
#         2.25386038e-03, 2.54962304e-04, 6.20450102e-04, 1.69921856e-04,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.35470125e-03,
#         1.57773645e-03, 6.72932796e-05, 2.48306439e-03, 1.03763014e-02,
#         8.01054519e-05, 2.24205695e-04, 9.88950022e-04, 1.91356038e-04,
#         3.74614399e-04, 0.00000000e+00, 6.16618824e-04, 1.73121184e-03,
#         4.65071853e-04, 1.61583278e-03, 0.00000000e+00, 1.91424689e-05,
#         6.22319092e-04, 4.04414737e-03, 1.48186652e-03, 1.77188593e-03,
#         4.33341908e-04, 7.72169257e-04, 2.17262145e-04, 1.03679224e-03,
#         2.13983919e-04, 0.00000000e+00, 1.76941537e-07, 1.28835192e-03,
#         7.26139855e-03, 8.89195617e-03, 3.02260224e-05, 0.00000000e+00,
#         1.13033934e-03, 1.48314678e-02, 7.07257207e-05, 0.00000000e+00,
#         3.79105961e-04, 9.34529472e-05, 2.75480938e-04, 0.00000000e+00,
#         2.39650087e-03, 5.42041397e-04, 2.42465718e-05, 0.00000000e+00,
#         6.39222390e-04, 4.64228904e-03, 6.34115394e-04, 1.10577077e-03,
#         5.20584302e-03, 0.00000000e+00, 2.37998816e-05, 0.00000000e+00,
#         2.51192833e-04, 0.00000000e+00, 2.03012868e-04, 0.00000000e+00,
#         1.30706486e-03, 0.00000000e+00, 6.91331268e-04, 2.80389335e-03,
#         6.27028963e-05, 0.00000000e+00, 0.00000000e+00, 3.25532630e-04,
#         2.04410904e-04, 4.18252468e-04, 3.43923892e-04, 0.00000000e+00,
#         5.27514990e-05, 4.52657933e-05, 2.29452232e-04, 4.19690791e-04,
#         1.85637634e-03, 1.79524154e-03, 4.13419825e-04, 0.00000000e+00,
#         1.34278011e-03, 2.82664184e-05, 0.00000000e+00, 7.59383553e-05,
#         1.99272830e-04, 1.97317693e-03, 0.00000000e+00, 0.00000000e+00,
#         3.48502311e-04, 0.00000000e+00, 6.78574280e-04, 6.56589141e-05,
#         0.00000000e+00, 2.59217560e-04, 2.27299847e-04, 1.73021687e-03,
#         0.00000000e+00, 3.96950504e-03, 9.20452962e-05, 2.14173881e-05,
#         1.95765747e-04, 0.00000000e+00, 0.00000000e+00, 3.61155727e-05,
#         4.83840161e-04, 2.58736270e-07, 0.00000000e+00, 1.44382294e-02,
#         8.09184871e-04, 0.00000000e+00, 0.00000000e+00, 3.40616486e-04,
#         1.45102371e-02, 0.00000000e+00, 1.80853966e-04, 2.70132303e-04,
#         1.09848027e-04, 3.96187330e-04, 6.02711571e-03, 6.23829736e-04,
#         0.00000000e+00, 5.78963543e-04, 4.08809880e-04, 1.88829998e-04,
#         0.00000000e+00, 8.29136792e-04, 5.23512804e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.84941993e-06,
#         3.37960190e-04, 3.74545304e-04, 4.05139692e-03, 2.62802715e-04,
#         0.00000000e+00, 0.00000000e+00, 4.60317410e-04, 1.68794473e-04,
#         1.89494908e-03, 1.00044187e-04, 2.33385837e-05, 2.27822185e-02,
#         1.91661747e-03, 0.00000000e+00, 0.00000000e+00, 2.38517304e-03,
#         1.35484105e-03, 2.60681130e-04, 0.00000000e+00, 0.00000000e+00,
#         8.13014902e-04, 1.29371312e-04, 1.15342887e-04, 6.44203694e-04,
#         1.35227119e-02, 2.64964304e-04, 6.30169012e-04, 0.00000000e+00,
#         3.52595046e-04, 0.00000000e+00, 4.39551685e-04, 2.42402348e-03,
#         0.00000000e+00, 9.48747637e-04, 0.00000000e+00, 4.74451987e-04,
#         0.00000000e+00, 0.00000000e+00, 1.84511753e-05, 1.90965366e-04,
#         2.75595118e-04, 6.28114730e-05, 1.06831330e-03, 8.56152002e-03,
#         0.00000000e+00, 8.15181354e-03, 3.42950545e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.69724704e-04, 0.00000000e+00,
#         0.00000000e+00, 3.28910209e-04, 3.78527930e-03, 1.53552214e-06,
#         4.55977374e-04, 2.37795326e-06, 1.45595975e-03, 1.36106132e-03,
#         2.68937847e-05, 3.38374413e-04, 0.00000000e+00, 2.75492276e-04,
#         1.15995011e-04, 2.15901614e-04, 4.98430937e-04, 3.55923347e-03,
#         1.05110208e-05, 1.55559125e-06, 1.02792832e-03, 2.34336487e-03,
#         8.63010978e-04, 4.68720361e-04, 1.05269100e-02, 7.10608994e-04,
#         5.94417064e-05, 1.48501213e-04, 7.71552247e-05, 3.62148784e-04,
#         2.26370111e-04, 3.71685890e-04, 0.00000000e+00, 6.53121431e-05,
#         8.75734959e-06, 0.00000000e+00, 5.99605502e-04, 0.00000000e+00,
#         2.07354798e-04, 1.56162004e-03, 1.85200138e-03, 1.83507162e-04,
#         1.27723579e-03, 0.00000000e+00, 2.77280059e-04, 0.00000000e+00,
#         1.74897950e-03, 1.35787450e-03, 9.14527914e-04, 1.71867524e-06,
#         2.42215228e-05, 2.14661299e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.21701439e-05, 2.10844877e-05,
#         0.00000000e+00, 2.08943550e-04, 0.00000000e+00, 3.63964441e-05,
#         2.53703539e-02, 0.00000000e+00, 1.75153958e-03, 1.29806127e-03,
#         1.55532298e-02, 4.82712122e-05, 7.98514251e-05, 1.20786043e-03,
#         1.87275707e-04, 2.77324778e-04, 2.82434017e-03, 5.91762791e-04,
#         0.00000000e+00, 1.19841270e-04, 3.66863872e-04, 2.91788524e-04,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.18127678e-04,
#         0.00000000e+00, 2.38092017e-04, 1.03894465e-03, 1.52727007e-03,
#         5.95135961e-04, 2.50853820e-04, 5.78445358e-04, 2.32409565e-04,
#         3.90505246e-04, 0.00000000e+00, 1.70570861e-03, 1.83289908e-04,
#         0.00000000e+00, 0.00000000e+00, 4.91106658e-06, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.12012352e-05,
#         3.55061946e-05, 2.99463863e-05, 0.00000000e+00, 8.40083010e-04,
#         8.71488031e-05, 0.00000000e+00, 8.27627633e-04, 5.60380488e-04,
#         1.41139767e-03, 4.40425308e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.95221044e-04, 2.35061006e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.97575222e-03, 0.00000000e+00,
#         0.00000000e+00, 5.85591438e-04, 6.23968576e-05, 2.78540666e-03,
#         5.29077607e-03, 4.89282603e-05, 2.80761095e-04, 0.00000000e+00,
#         3.28233776e-04, 1.99650776e-04, 1.99521692e-03, 0.00000000e+00,
#         7.93890618e-04, 1.67410213e-03, 7.78360538e-05, 5.02779405e-05,
#         0.00000000e+00, 3.18299970e-05, 1.60224841e-04, 2.06266090e-05,
#         4.32065895e-04, 4.53074113e-04, 0.00000000e+00, 0.00000000e+00,
#         5.46211683e-03, 0.00000000e+00, 3.38232359e-05, 7.28592585e-04,
#         1.44779295e-06, 2.37441919e-05, 3.81261007e-04, 0.00000000e+00,
#         0.00000000e+00, 1.23376025e-04, 0.00000000e+00, 0.00000000e+00,
#         1.42948128e-01, 8.18707708e-04, 3.24862392e-03, 0.00000000e+00,
#         7.39113945e-04, 1.32235574e-03, 0.00000000e+00, 9.03528902e-06,
#         0.00000000e+00, 5.11730495e-05, 0.00000000e+00, 2.48053808e-03,
#         3.30297270e-05, 3.74082140e-04, 0.00000000e+00, 5.61146546e-05,
#         2.37803949e-05, 1.86551828e-04, 1.26753029e-04, 0.00000000e+00,
#         0.00000000e+00, 1.52357229e-03, 4.51178859e-04, 2.95615302e-05,
#         0.00000000e+00, 2.16907666e-04, 2.63063720e-03, 0.00000000e+00,
#         3.02537957e-03, 1.41169816e-04, 8.20310056e-04, 1.71639115e-03,
#         0.00000000e+00, 3.61465112e-05, 0.00000000e+00, 3.99053097e-05,
#         0.00000000e+00, 6.68518974e-05, 4.14555832e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.18938067e-03, 0.00000000e+00,
#         0.00000000e+00, 3.05669029e-03, 6.04996867e-05, 4.27205386e-05,
#         1.00887427e-03, 0.00000000e+00, 4.34846895e-04, 5.59388022e-04,
#         1.35689636e-03, 3.15807734e-04, 3.57786349e-04, 0.00000000e+00,
#         0.00000000e+00, 2.32017552e-04, 0.00000000e+00, 1.88082974e-04,
#         2.68341063e-04, 5.82947441e-04, 2.85539098e-03, 0.00000000e+00,
#         2.04427957e-04, 1.16292376e-04, 0.00000000e+00, 5.97268809e-05,
#         2.01705895e-04, 9.64675558e-04, 1.06642007e-03, 0.00000000e+00,
#         0.00000000e+00, 5.92256051e-05, 0.00000000e+00, 0.00000000e+00,
#         4.93540860e-05, 7.17348820e-04, 4.20699138e-04, 2.28731251e-05,
#         0.00000000e+00, 6.31299954e-04, 3.60813292e-03, 0.00000000e+00,
#         1.58705076e-03, 0.00000000e+00, 8.06914010e-03, 8.52789902e-04,
#         4.90832651e-05, 3.01961992e-04, 0.00000000e+00, 2.40580903e-03,
#         0.00000000e+00, 2.03733936e-04, 2.10923867e-04, 7.18499258e-04,
#         0.00000000e+00, 2.17550865e-04, 1.10470780e-03, 0.00000000e+00,
#         1.32271780e-04, 0.00000000e+00, 3.86579199e-04, 4.67442222e-03,
#         4.45858222e-04, 3.42526607e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.06260568e-04, 2.50522780e-04,
#         0.00000000e+00, 2.27697504e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.67146695e-04,
#         0.00000000e+00, 1.52795703e-03, 4.49823041e-04, 2.53028034e-05,
#         0.00000000e+00, 7.11705083e-04, 2.87742695e-05, 4.72574255e-06,
#         9.75839688e-04, 0.00000000e+00, 0.00000000e+00, 3.70712326e-05,
#         0.00000000e+00, 8.06383523e-03, 5.16910856e-03, 7.25014456e-04,
#         2.00344966e-03, 1.57805707e-03, 3.59486363e-03, 2.57334080e-05,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         7.47763056e-05, 1.26655248e-02, 0.00000000e+00, 0.00000000e+00,
#         2.33250739e-04, 0.00000000e+00, 6.82553315e-04, 8.47185854e-04,
#         6.12826078e-05, 8.68457930e-04, 4.04850264e-04, 0.00000000e+00,
#         4.06162451e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         4.08356233e-04, 5.62154628e-05, 0.00000000e+00, 5.59499625e-05,
#         0.00000000e+00, 4.95539150e-05, 5.67752889e-06, 0.00000000e+00,
#         0.00000000e+00, 2.55193749e-04, 2.61843219e-03, 4.14155404e-04,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.50086570e-04,
#         4.42233971e-04, 4.31743244e-04, 4.65069139e-04, 0.00000000e+00,
#         1.76515941e-03, 0.00000000e+00, 2.97690806e-04, 8.44383950e-04,
#         2.92245059e-03, 6.09505521e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         4.41686500e-05, 0.00000000e+00, 1.39547102e-02, 4.92884590e-04,
#         0.00000000e+00, 4.02503169e-04, 2.51363790e-05, 3.68812525e-06,
#         9.46571899e-03, 1.71257175e-04, 0.00000000e+00, 1.42158711e-06,
#         0.00000000e+00, 3.14857936e-05, 2.02742905e-04, 2.42806833e-05,
#         6.94745520e-04, 3.96182347e-04, 5.69793474e-03, 2.42255626e-03,
#         0.00000000e+00, 2.33152071e-04, 3.00628965e-05, 0.00000000e+00,
#         0.00000000e+00, 1.26757961e-05, 0.00000000e+00, 7.42543877e-05,
#         5.85360608e-04, 5.71180549e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.15677314e-02, 1.43751138e-03, 1.94405602e-04,
#         0.00000000e+00, 3.22076742e-05, 2.01636580e-04, 0.00000000e+00,
#         2.80395789e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.40848562e-03, 4.06143135e-04, 6.72697260e-06, 1.96278250e-04,
#         0.00000000e+00, 3.56177736e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 3.11180221e-04, 0.00000000e+00, 2.16331423e-05,
#         6.01047779e-05, 0.00000000e+00, 0.00000000e+00, 9.05278076e-04,
#         5.05495797e-03, 0.00000000e+00, 1.76286267e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.06581351e-04,
#         4.96322034e-03, 2.50368368e-02, 2.32383846e-05, 4.57069284e-06,
#         1.84204864e-03, 1.20894814e-03, 0.00000000e+00, 0.00000000e+00,
#         1.78530883e-05, 2.27133989e-05, 3.02209894e-04, 2.48731260e-03,
#         0.00000000e+00, 5.40275640e-05, 2.43528530e-04, 2.00857240e-04,
#         0.00000000e+00, 0.00000000e+00, 3.68957615e-04, 2.07267615e-04,
#         9.91358603e-06, 1.54737446e-03, 3.59824255e-04, 2.97979417e-05,
#         0.00000000e+00, 0.00000000e+00, 3.59516452e-03, 2.08224206e-03,
#         7.30163150e-06, 5.75506958e-07, 0.00000000e+00, 1.88672260e-04,
#         0.00000000e+00, 1.62388057e-03, 0.00000000e+00, 2.16573442e-04,
#         3.82845437e-04, 0.00000000e+00, 7.51631481e-04, 3.20317513e-05,
#         2.68231118e-04, 6.26481132e-06, 2.19094539e-04, 1.39615925e-06,
#         0.00000000e+00, 9.92389064e-04, 5.20026501e-04, 0.00000000e+00,
#         2.68435750e-03, 4.26369616e-04, 5.33097120e-04, 1.70528992e-04,
#         2.18379923e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.54675899e-04, 0.00000000e+00, 0.00000000e+00, 4.14558497e-05,
#         0.00000000e+00, 9.54873790e-05, 0.00000000e+00, 2.01083907e-04,
#         2.32222406e-04, 1.53275116e-03, 0.00000000e+00, 2.09729661e-05,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.58202409e-04, 4.45464076e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.51378551e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.35194104e-06, 0.00000000e+00, 0.00000000e+00,
#         2.39412917e-05, 1.99264485e-04, 2.30527151e-05, 1.65248945e-04,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.58653545e-05,
#         0.00000000e+00, 1.05424271e-04, 1.74560256e-04, 0.00000000e+00])}

# %%
clf = xgb.XGBClassifier(**parameters).fit(filtered_data_01, y)

list(sorted(zip(clf.feature_importances_, filtered_data_01.columns), reverse = True))
# Out:
# [(0.17600389, 'IL1A'),
#  (0.08085336, 'NKAIN1'),
#  (0.040582884, 'FSIP1'),
#  (0.033085812, 'SAMD9L'),
#  (0.025526734, 'EBI3'),
#  (0.024465673, 'IFI16'),
#  (0.024256032, 'CXCL1'),
#  (0.023557836, 'NRTN'),
#  (0.02271954, 'UBE2L6'),
#  (0.020057864, 'FHL5'),
#  (0.018765423, 'DCLK1'),
#  (0.016079819, 'PHF11'),
#  (0.0154207535, 'THEMIS2'),
#  (0.015012367, 'GBP2'),
#  (0.014706367, 'GFPT2'),
#  (0.014257988, 'HCN4'),
#  (0.012703476, 'HERC5'),
#  (0.012473829, 'TNFRSF9'),
#  (0.012232057, 'PDZK1IP1'),
#  (0.011772433, 'SSH1'),
#  (0.011768914, 'CFB'),
#  (0.0113923615, 'CASP4'),
#  (0.011376115, 'CLDN16'),
#  (0.011316258, 'MOCOS'),
#  (0.011273014, 'NMNAT1'),
#  (0.011028717, 'SPATA21'),
#  (0.010886526, 'KRT35'),
#  (0.010886447, 'GCH1'),
#  (0.010847612, 'KYNU'),
#  (0.010838783, 'ICAM1'),
#  (0.010381575, 'IFIT3'),
#  (0.01029181, 'TLR2'),
#  (0.010231779, 'FBLIM1'),
#  (0.010216653, 'FHDC1'),
#  (0.0100672785, 'CCBE1'),
#  (0.0100054415, 'STX12'),
#  (0.009745724, 'MT2A'),
#  (0.009466907, 'SAA1'),
#  (0.009324187, 'ZBTB25'),
#  (0.00850817, 'CX3CL1'),
#  (0.0084484, 'C22orf24'),
#  (0.00841534, 'RGS17'),
#  (0.008375631, 'TRANK1'),
#  (0.0072352546, 'GRID1'),
#  (0.0071678855, 'PTPRH'),
#  (0.0069087455, 'IFITM1'),
#  (0.00671411, 'IFI44'),
#  (0.006313306, 'SAMD9'),
#  (0.006094396, 'FAM49A'),
#  (0.005840077, 'SYTL2'),
#  (0.0057885097, 'SLC6A4'),
#  (0.005750677, 'ADD2'),
#  (0.005501322, 'PCK2'),
#  (0.0048963465, 'CXCL5'),
#  (0.0046806564, 'ANKRD26P1'),
#  (0.004661512, 'CATSPER2P1'),
#  (0.0039128438, 'MCAM'),
#  (0.0038518913, 'IRF2BPL'),
#  (0.0037954866, 'IGFBP1'),
#  (0.003605925, 'PPP1R16B'),
#  (0.0036029702, 'ARHGEF4'),
#  (0.0033383616, 'ZNF862'),
#  (0.0033195938, 'LOC254896'),
#  (0.0027396476, 'PITPNA-AS1'),
#  (0.0026866167, 'MOBP'),
#  (0.0024782463, 'IRF7'),
#  (0.0024726028, 'IFIT2'),
#  (0.0024312884, 'CCL20'),
#  (0.0023584287, 'GPSM3'),
#  (0.002285202, 'MYPN'),
#  (0.00224662, 'HBEGF'),
#  (0.0020616972, 'TRABD2A'),
#  (0.0019617586, 'ADORA2A'),
#  (0.0019567946, 'ZNF239'),
#  (0.0018695239, 'CCL5'),
#  (0.0018346598, 'PLIN2'),
#  (0.0016613477, 'JUN'),
#  (0.0016151221, 'BMPER'),
#  (0.0016047613, 'TFF1'),
#  (0.0015496068, 'STC2'),
#  (0.0015288289, 'FOXD1'),
#  (0.0014287918, 'RPL36A'),
#  (0.001279294, 'MAP1B'),
#  (0.0012613586, 'NMI'),
#  (0.001198736, 'PARP10'),
#  (0.0011948865, 'C3AR1'),
#  (0.0009766634, 'MB'),
#  (0.0007900419, 'CCL2'),
#  (0.0005499405, 'XAF1'),
#  (0.00041824847, 'HSF2BP'),
#  (0.00041759497, 'REEP2'),
#  (0.00024696797, 'PI3'),
#  (0.00020991582, 'DAW1'),
#  (7.712663e-05, 'TCTE3'),
#  (0.0, 'ZSCAN9'),
#  (0.0, 'ZSCAN29'),
#  (0.0, 'ZNFX1'),
#  (0.0, 'ZNF853'),
#  (0.0, 'ZNF850'),
#  (0.0, 'ZNF841'),
#  (0.0, 'ZNF774'),
#  (0.0, 'ZNF773'),
#  (0.0, 'ZNF77'),
#  (0.0, 'ZNF720'),
#  (0.0, 'ZNF669'),
#  (0.0, 'ZNF606'),
#  (0.0, 'ZNF583'),
#  (0.0, 'ZNF566'),
#  (0.0, 'ZNF555'),
#  (0.0, 'ZNF550'),
#  (0.0, 'ZNF549'),
#  (0.0, 'ZNF544'),
#  (0.0, 'ZNF525'),
#  (0.0, 'ZNF419'),
#  (0.0, 'ZNF34'),
#  (0.0, 'ZNF322'),
#  (0.0, 'ZNF28'),
#  (0.0, 'ZNF274'),
#  (0.0, 'ZNF235'),
#  (0.0, 'ZNF229'),
#  (0.0, 'ZNF160'),
#  (0.0, 'ZNF136'),
#  (0.0, 'ZMYND12'),
#  (0.0, 'ZFP28'),
#  (0.0, 'ZCWPW1'),
#  (0.0, 'ZCCHC9'),
#  (0.0, 'ZBTB46'),
#  (0.0, 'YEATS2'),
#  (0.0, 'XDH'),
#  (0.0, 'WWC2'),
#  (0.0, 'WTAPP1'),
#  (0.0, 'WISP2'),
#  (0.0, 'WHAMMP1'),
#  (0.0, 'WDR41'),
#  (0.0, 'WDPCP'),
#  (0.0, 'VTRNA1-1'),
#  (0.0, 'VSTM1'),
#  (0.0, 'VNN1'),
#  (0.0, 'VEGFA'),
#  (0.0, 'VDAC2'),
#  (0.0, 'VAV1'),
#  (0.0, 'UTP23'),
#  (0.0, 'USP53'),
#  (0.0, 'USP40'),
#  (0.0, 'USP16'),
#  (0.0, 'USP12'),
#  (0.0, 'UGCG'),
#  (0.0, 'UBC'),
#  (0.0, 'UBASH3B'),
#  (0.0, 'UACA'),
#  (0.0, 'TYMP'),
#  (0.0, 'TXNDC9'),
#  (0.0, 'TUBB2B'),
#  (0.0, 'TTC39B'),
#  (0.0, 'TTC25'),
#  (0.0, 'TSGA10'),
#  (0.0, 'TRMT10B'),
#  (0.0, 'TRIP4'),
#  (0.0, 'TRIM36'),
#  (0.0, 'TRIM25'),
#  (0.0, 'TRIM16L'),
#  (0.0, 'TRIB3'),
#  (0.0, 'TREML3P'),
#  (0.0, 'TRAF1'),
#  (0.0, 'TPM4'),
#  (0.0, 'TPBG'),
#  (0.0, 'TOX2'),
#  (0.0, 'TOR1B'),
#  (0.0, 'TNNT1'),
#  (0.0, 'TNNI3'),
#  (0.0, 'TNIP1'),
#  (0.0, 'TNFRSF10B'),
#  (0.0, 'TNFAIP3'),
#  (0.0, 'TNFAIP2'),
#  (0.0, 'TNF'),
#  (0.0, 'TMEM9B-AS1'),
#  (0.0, 'TMEM44'),
#  (0.0, 'TMEM26'),
#  (0.0, 'TMEM255A'),
#  (0.0, 'TMEM241'),
#  (0.0, 'TMEM156'),
#  (0.0, 'TMEM150B'),
#  (0.0, 'TMEM130'),
#  (0.0, 'TMEM128'),
#  (0.0, 'TMEM106A'),
#  (0.0, 'TMC8'),
#  (0.0, 'TMC6'),
#  (0.0, 'TM6SF1'),
#  (0.0, 'TLE1'),
#  (0.0, 'TIPARP'),
#  (0.0, 'TIGD7'),
#  (0.0, 'THSD4'),
#  (0.0, 'THBD'),
#  (0.0, 'THAP6'),
#  (0.0, 'TGM4'),
#  (0.0, 'TGFBR3L'),
#  (0.0, 'TGFA'),
#  (0.0, 'TEC'),
#  (0.0, 'TDRD7'),
#  (0.0, 'TDRD12'),
#  (0.0, 'TCEAL4'),
#  (0.0, 'TBX15'),
#  (0.0, 'TAS2R5'),
#  (0.0, 'TAS2R31'),
#  (0.0, 'TAPBP'),
#  (0.0, 'TAP1'),
#  (0.0, 'SYT9'),
#  (0.0, 'SYT1'),
#  (0.0, 'SYNGR3'),
#  (0.0, 'SYN2'),
#  (0.0, 'SVEP1'),
#  (0.0, 'SUSD3'),
#  (0.0, 'STYXL1'),
#  (0.0, 'STX2'),
#  (0.0, 'STX11'),
#  (0.0, 'STC1'),
#  (0.0, 'STAT5A'),
#  (0.0, 'STAT4'),
#  (0.0, 'STAT2'),
#  (0.0, 'STAT1'),
#  (0.0, 'STARD13'),
#  (0.0, 'STAC'),
#  (0.0, 'ST3GAL5'),
#  (0.0, 'SSR3'),
#  (0.0, 'SRPX'),
#  (0.0, 'SRGN'),
#  (0.0, 'SRD5A2'),
#  (0.0, 'SPTBN4'),
#  (0.0, 'SPRY1'),
#  (0.0, 'SPOCD1'),
#  (0.0, 'SPINT1'),
#  (0.0, 'SP140L'),
#  (0.0, 'SP110'),
#  (0.0, 'SP100'),
#  (0.0, 'SOWAHC'),
#  (0.0, 'SOD2'),
#  (0.0, 'SOCS6'),
#  (0.0, 'SOCS3'),
#  (0.0, 'SOCS2'),
#  (0.0, 'SNX16'),
#  (0.0, 'SNORD83A'),
#  (0.0, 'SNORD19'),
#  (0.0, 'SNORA12'),
#  (0.0, 'SNAPC1'),
#  (0.0, 'SMS'),
#  (0.0, 'SLCO4C1'),
#  (0.0, 'SLC35G2'),
#  (0.0, 'SLC25A37'),
#  (0.0, 'SLC22A2'),
#  (0.0, 'SLC17A4'),
#  (0.0, 'SLC10A5'),
#  (0.0, 'SIPA1L2'),
#  (0.0, 'SIDT1'),
#  (0.0, 'SHOX2'),
#  (0.0, 'SH3RF1'),
#  (0.0, 'SGCB'),
#  (0.0, 'SERTAD4-AS1'),
#  (0.0, 'SERPINE2'),
#  (0.0, 'SERPINB8'),
#  (0.0, 'SERPINB7'),
#  (0.0, 'SERPINB4'),
#  (0.0, 'SERPINB3'),
#  (0.0, 'SEMA6B'),
#  (0.0, 'SEMA4B'),
#  (0.0, 'SEMA3C'),
#  (0.0, 'SELE'),
#  (0.0, 'SEL1L3'),
#  (0.0, 'SDR16C5'),
#  (0.0, 'SDE2'),
#  (0.0, 'SDC4'),
#  (0.0, 'SCRN1'),
#  (0.0, 'SCN4A'),
#  (0.0, 'SCG5'),
#  (0.0, 'SCARB2'),
#  (0.0, 'SAT1'),
#  (0.0, 'SAMD4A'),
#  (0.0, 'SAA2'),
#  (0.0, 'S1PR1'),
#  (0.0, 'RUSC2'),
#  (0.0, 'RUNDC3B'),
#  (0.0, 'RSPH9'),
#  (0.0, 'RSL1D1'),
#  (0.0, 'RRAS2'),
#  (0.0, 'RPS18'),
#  (0.0, 'RPS15A'),
#  (0.0, 'RPL7L1'),
#  (0.0, 'RPL22L1'),
#  (0.0, 'ROR1'),
#  (0.0, 'RNF32'),
#  (0.0, 'RNF24'),
#  (0.0, 'RIOK3'),
#  (0.0, 'RIN2'),
#  (0.0, 'RHOB'),
#  (0.0, 'RHCG'),
#  (0.0, 'RGS11'),
#  (0.0, 'RGS10'),
#  (0.0, 'RFXAP'),
#  (0.0, 'RELB'),
#  (0.0, 'RBP7'),
#  (0.0, 'RASGRP2'),
#  (0.0, 'RASA3'),
#  (0.0, 'RAP1GAP2'),
#  (0.0, 'RAD52'),
#  (0.0, 'RAB3B'),
#  (0.0, 'RAB33B'),
#  (0.0, 'QSOX1'),
#  (0.0, 'QPCT'),
#  (0.0, 'PXDN'),
#  (0.0, 'PXDC1'),
#  (0.0, 'PVR'),
#  (0.0, 'PTX3'),
#  (0.0, 'PTPRF'),
#  (0.0, 'PTPRE'),
#  (0.0, 'PTPN3'),
#  (0.0, 'PTPDC1'),
#  (0.0, 'PTK2B'),
#  (0.0, 'PTGES'),
#  (0.0, 'PTENP1'),
#  (0.0, 'PTAFR'),
#  (0.0, 'PSME1'),
#  (0.0, 'PSMD7'),
#  (0.0, 'PRTN3'),
#  (0.0, 'PRSS22'),
#  (0.0, 'PRPF18'),
#  (0.0, 'PRKCG'),
#  (0.0, 'PRKCE'),
#  (0.0, 'PRKAG2-AS1'),
#  (0.0, 'PRKAG2'),
#  (0.0, 'PPP3CC'),
#  (0.0, 'PPP1R3C'),
#  (0.0, 'PPP1R3B'),
#  (0.0, 'PPP1R26'),
#  (0.0, 'PPP1R15B'),
#  (0.0, 'PPM1K'),
#  (0.0, 'PPFIBP1'),
#  (0.0, 'PNPT1'),
#  (0.0, 'PNPLA4'),
#  (0.0, 'PNMA2'),
#  (0.0, 'PMEL'),
#  (0.0, 'PMAIP1'),
#  (0.0, 'PLTP'),
#  (0.0, 'PLSCR2'),
#  (0.0, 'PLSCR1'),
#  (0.0, 'PLOD2'),
#  (0.0, 'PLEKHA4'),
#  (0.0, 'PLEKHA2'),
#  (0.0, 'PLAUR'),
#  (0.0, 'PLA2R1'),
#  (0.0, 'PKDREJ'),
#  (0.0, 'PIWIL2'),
#  (0.0, 'PIPOX'),
#  (0.0, 'PIP5KL1'),
#  (0.0, 'PIK3CD'),
#  (0.0, 'PHLDA1'),
#  (0.0, 'PHF20'),
#  (0.0, 'PGM5P2'),
#  (0.0, 'PFKP'),
#  (0.0, 'PEAR1'),
#  (0.0, 'PDK1'),
#  (0.0, 'PDGFC'),
#  (0.0, 'PDGFB'),
#  (0.0, 'PDGFA'),
#  (0.0, 'PCOLCE2'),
#  (0.0, 'PCDH1'),
#  (0.0, 'PAXBP1-AS1'),
#  (0.0, 'PARP9'),
#  (0.0, 'PARP8'),
#  (0.0, 'PARP14'),
#  (0.0, 'PARP12'),
#  (0.0, 'PARD3B'),
#  (0.0, 'PAQR5'),
#  (0.0, 'P4HA2'),
#  (0.0, 'P4HA1'),
#  (0.0, 'P2RX5'),
#  (0.0, 'OSBPL1A'),
#  (0.0, 'OPTN'),
#  (0.0, 'OMP'),
#  (0.0, 'OLR1'),
#  (0.0, 'OGFRL1'),
#  (0.0, 'ODF3B'),
#  (0.0, 'OASL'),
#  (0.0, 'OAS2'),
#  (0.0, 'NYAP1'),
#  (0.0, 'NUFIP1'),
#  (0.0, 'NUCB2'),
#  (0.0, 'NUAK2'),
#  (0.0, 'NTN4'),
#  (0.0, 'NT5E'),
#  (0.0, 'NT5C2'),
#  (0.0, 'NSRP1'),
#  (0.0, 'NPAS2'),
#  (0.0, 'NOMO3'),
#  (0.0, 'NOG'),
#  (0.0, 'NLGN4Y'),
#  (0.0, 'NKX3-1'),
#  (0.0, 'NKX2-8'),
#  (0.0, 'NIPAL1'),
#  (0.0, 'NGEF'),
#  (0.0, 'NFKBIZ'),
#  (0.0, 'NFKBIA'),
#  (0.0, 'NFKB2'),
#  (0.0, 'NFKB1'),
#  (0.0, 'NFE2L3'),
#  (0.0, 'NEFL'),
#  (0.0, 'NCOA7'),
#  (0.0, 'NCEH1'),
#  (0.0, 'NAV3'),
#  (0.0, 'NALCN'),
#  (0.0, 'NACA'),
#  (0.0, 'NAB1'),
#  (0.0, 'N4BP3'),
#  (0.0, 'N4BP2L1'),
#  (0.0, 'MYO18B'),
#  (0.0, 'MYBL1'),
#  (0.0, 'MX1'),
#  (0.0, 'MST1'),
#  (0.0, 'MREG'),
#  (0.0, 'MOB3C'),
#  (0.0, 'MMP11'),
#  (0.0, 'MMP10'),
#  (0.0, 'MIR635'),
#  (0.0, 'MIR4754'),
#  (0.0, 'MIR4746'),
#  (0.0, 'MIR21'),
#  (0.0, 'MICAL2'),
#  (0.0, 'MEFV'),
#  (0.0, 'MED30'),
#  (0.0, 'MCTP1'),
#  (0.0, 'MATN3'),
#  (0.0, 'MARVELD3'),
#  (0.0, 'MAP3K13'),
#  (0.0, 'MAP2'),
#  (0.0, 'MAP1LC3B'),
#  (0.0, 'MANSC4'),
#  (0.0, 'MAML2'),
#  (0.0, 'MAFF'),
#  (0.0, 'LUZP1'),
#  (0.0, 'LTB'),
#  (0.0, 'LRSAM1'),
#  (0.0, 'LRRD1'),
#  (0.0, 'LRRC57'),
#  (0.0, 'LRRC42'),
#  (0.0, 'LRRC37B'),
#  (0.0, 'LRP12'),
#  (0.0, 'LOXL2'),
#  (0.0, 'LONRF3'),
#  (0.0, 'LOC728730'),
#  (0.0, 'LOC728024'),
#  (0.0, 'LOC400655'),
#  (0.0, 'LOC389641'),
#  (0.0, 'LOC374443'),
#  (0.0, 'LOC100507053'),
#  (0.0, 'LOC100506801'),
#  (0.0, 'LOC100288911'),
#  (0.0, 'LOC100268168'),
#  (0.0, 'LIPT1'),
#  (0.0, 'LIPH'),
#  (0.0, 'LINC00856'),
#  (0.0, 'LINC00696'),
#  (0.0, 'LINC00662'),
#  (0.0, 'LINC00629'),
#  (0.0, 'LINC00525'),
#  (0.0, 'LINC00239'),
#  (0.0, 'LIF'),
#  (0.0, 'LETM2'),
#  (0.0, 'LCP1'),
#  (0.0, 'LCN2'),
#  (0.0, 'LAT2'),
#  (0.0, 'LAMP3'),
#  (0.0, 'LAMC2'),
#  (0.0, 'LAMB3'),
#  (0.0, 'LAMA4'),
#  (0.0, 'L1CAM'),
#  (0.0, 'KTN1-AS1'),
#  (0.0, 'KTN1'),
#  (0.0, 'KRT80'),
#  (0.0, 'KRT34'),
#  (0.0, 'KPNA3'),
#  (0.0, 'KLHL29'),
#  (0.0, 'KLHL2'),
#  (0.0, 'KLF6'),
#  (0.0, 'KLF2'),
#  (0.0, 'KLC1'),
#  (0.0, 'KIAA0319'),
#  (0.0, 'KDM3A'),
#  (0.0, 'KCTD19'),
#  (0.0, 'KCTD11'),
#  (0.0, 'KCNQ3'),
#  (0.0, 'KCNK6'),
#  (0.0, 'JOSD1'),
#  (0.0, 'JDP2'),
#  (0.0, 'JAK3'),
#  (0.0, 'ITPRIP'),
#  (0.0, 'ITPR3'),
#  (0.0, 'ITGA7'),
#  (0.0, 'ITGA3'),
#  (0.0, 'ITGA2B'),
#  (0.0, 'ISG20'),
#  (0.0, 'IRF9'),
#  (0.0, 'IRF1'),
#  (0.0, 'IRAK2'),
#  (0.0, 'INSR'),
#  (0.0, 'INPP5F'),
#  (0.0, 'INPP5B'),
#  (0.0, 'INPP1'),
#  (0.0, 'INHBE'),
#  (0.0, 'IL7R'),
#  (0.0, 'IL7'),
#  (0.0, 'IL6'),
#  (0.0, 'IL32'),
#  (0.0, 'IL31RA'),
#  (0.0, 'IL23A'),
#  (0.0, 'IL1RAP'),
#  (0.0, 'IL1B'),
#  (0.0, 'IL15RA'),
#  (0.0, 'IL12B'),
#  (0.0, 'IL12A'),
#  (0.0, 'IL10RB'),
#  (0.0, 'IGFL2'),
#  (0.0, 'IFNK'),
#  (0.0, 'IFNAR2'),
#  (0.0, 'IFIT5'),
#  (0.0, 'IFIH1'),
#  (0.0, 'IER3'),
#  (0.0, 'IAH1'),
#  (0.0, 'HTR7'),
#  (0.0, 'HSPB6'),
#  (0.0, 'HSPA1L'),
#  (0.0, 'HSPA12A'),
#  (0.0, 'HSD17B14'),
#  (0.0, 'HSD11B1L'),
#  (0.0, 'HSD11B1'),
#  (0.0, 'HSCB'),
#  (0.0, 'HSBP1L1'),
#  (0.0, 'HMGN2P46'),
#  (0.0, 'HLA-F'),
#  (0.0, 'HLA-C'),
#  (0.0, 'HLA-B'),
#  (0.0, 'HKDC1'),
#  (0.0, 'HK2'),
#  (0.0, 'HHIP'),
#  (0.0, 'HERC6'),
#  (0.0, 'HERC4'),
#  (0.0, 'HEG1'),
#  (0.0, 'HEBP1'),
#  (0.0, 'HCST'),
#  (0.0, 'HCAR3'),
#  (0.0, 'HAUS4'),
#  (0.0, 'H2BFXP'),
#  (0.0, 'GTF2F2'),
#  (0.0, 'GSPT2'),
#  (0.0, 'GRIP1'),
#  (0.0, 'GRIN3B'),
#  (0.0, 'GRIN2B'),
#  (0.0, 'GREM1'),
#  (0.0, 'GPX4'),
#  (0.0, 'GPR55'),
#  (0.0, 'GPR19'),
#  (0.0, 'GPR161'),
#  (0.0, 'GPR137B'),
#  (0.0, 'GOLGA8A'),
#  (0.0, 'GK'),
#  (0.0, 'GJB2'),
#  (0.0, 'GINM1'),
#  (0.0, 'GID4'),
#  (0.0, 'GFPT1'),
#  (0.0, 'GCNT4'),
#  (0.0, 'GBP3'),
#  (0.0, 'GBP1'),
#  (0.0, 'GATAD1'),
#  (0.0, 'GATA6'),
#  (0.0, 'GADD45A'),
#  (0.0, 'FXYD5'),
#  (0.0, 'FTH1'),
#  (0.0, 'FSTL1'),
#  (0.0, 'FRRS1'),
#  (0.0, 'FRMD6'),
#  (0.0, 'FOXL1'),
#  (0.0, 'FOXE1'),
#  (0.0, 'FOXD4L3'),
#  (0.0, 'FOSL1'),
#  (0.0, 'FNDC4'),
#  (0.0, 'FNDC1'),
#  (0.0, 'FMNL2'),
#  (0.0, 'FKBP14'),
#  (0.0, 'FILIP1L'),
#  (0.0, 'FICD'),
#  (0.0, 'FHL1'),
#  (0.0, 'FFAR2'),
#  (0.0, 'FEV'),
#  (0.0, 'FBXO27'),
#  (0.0, 'FAS-AS1'),
#  (0.0, 'FAM76A'),
#  (0.0, 'FAM221A'),
#  (0.0, 'FAM161A'),
#  (0.0, 'FAM131B'),
#  (0.0, 'FAM118A'),
#  (0.0, 'FAM110C'),
#  (0.0, 'F3'),
#  (0.0, 'EXT1'),
#  (0.0, 'EVX1'),
#  (0.0, 'ETV7'),
#  (0.0, 'ETS1'),
#  (0.0, 'ESPNL'),
#  (0.0, 'ESF1'),
#  (0.0, 'ERRFI1'),
#  (0.0, 'ERN1'),
#  (0.0, 'EREG'),
#  (0.0, 'EPHA2'),
#  (0.0, 'EMP1'),
#  (0.0, 'ELOVL7'),
#  (0.0, 'ELL2'),
#  (0.0, 'EIF2AK2'),
#  (0.0, 'EFNA5'),
#  (0.0, 'EFNA1'),
#  (0.0, 'EFEMP1'),
#  (0.0, 'EEF1A2'),
#  (0.0, 'EEF1A1'),
#  (0.0, 'EDEM3'),
#  (0.0, 'DUSP5'),
#  (0.0, 'DUSP16'),
#  (0.0, 'DUSP1'),
#  (0.0, 'DTX3L'),
#  (0.0, 'DRAM1'),
#  (0.0, 'DNAJC27-AS1'),
#  (0.0, 'DNAJC21'),
#  (0.0, 'DNAJC1'),
#  (0.0, 'DMC1'),
#  (0.0, 'DLL1'),
#  (0.0, 'DLEU2L'),
#  (0.0, 'DKK3'),
#  (0.0, 'DIRC3'),
#  (0.0, 'DHRS7'),
#  (0.0, 'DHRS13'),
#  (0.0, 'DGKD'),
#  (0.0, 'DENND5A'),
#  (0.0, 'DDX60L'),
#  (0.0, 'DDX60'),
#  (0.0, 'DDX58'),
#  (0.0, 'DDIT4'),
#  (0.0, 'DARS'),
#  (0.0, 'CYS1'),
#  (0.0, 'CYR61'),
#  (0.0, 'CYP39A1'),
#  (0.0, 'CYP20A1'),
#  (0.0, 'CYP1B1'),
#  (0.0, 'CYB5R2'),
#  (0.0, 'CXorf38'),
#  (0.0, 'CXCL6'),
#  (0.0, 'CXCL3'),
#  (0.0, 'CXCL2'),
#  (0.0, 'CTSS'),
#  (0.0, 'CTPS1'),
#  (0.0, 'CTNNAL1'),
#  (0.0, 'CTGF'),
#  (0.0, 'CTF1'),
#  (0.0, 'CSGALNACT1'),
#  (0.0, 'CSF3'),
#  (0.0, 'CSF2'),
#  (0.0, 'CSF1'),
#  (0.0, 'CRMP1'),
#  (0.0, 'CRLF3'),
#  (0.0, 'CRLF2'),
#  (0.0, 'CRKL'),
#  (0.0, 'CRISP3'),
#  (0.0, 'CPQ'),
#  (0.0, 'CPM'),
#  (0.0, 'CPAMD8'),
#  (0.0, 'COQ10B'),
#  (0.0, 'COL5A2'),
#  (0.0, 'COL4A6'),
#  (0.0, 'COL4A5'),
#  (0.0, 'COL2A1'),
#  (0.0, 'COL12A1'),
#  (0.0, 'COBLL1'),
#  (0.0, 'CNKSR3'),
#  (0.0, 'CNIH3'),
#  (0.0, 'CMTM3'),
#  (0.0, 'CLMP'),
#  (0.0, 'CLGN'),
#  (0.0, 'CLEC4E'),
#  (0.0, 'CLDN1'),
#  (0.0, 'CLCN4'),
#  (0.0, 'CHST11'),
#  (0.0, 'CHRM3'),
#  (0.0, 'CFLAR'),
#  (0.0, 'CEP290'),
#  (0.0, 'CELF5'),
#  (0.0, 'CDKL2'),
#  (0.0, 'CDKL1'),
#  (0.0, 'CDH3'),
#  (0.0, 'CDH15'),
#  (0.0, 'CDCP1'),
#  (0.0, 'CD8A'),
#  (0.0, 'CD68'),
#  (0.0, 'CD55'),
#  (0.0, 'CD47'),
#  (0.0, 'CD44'),
#  (0.0, 'CD40'),
#  (0.0, 'CD274'),
#  (0.0, 'CD22'),
#  (0.0, 'CCDC91'),
#  (0.0, 'CCDC170'),
#  (0.0, 'CCDC15'),
#  (0.0, 'CBWD3'),
#  (0.0, 'CAV2'),
#  (0.0, 'CASP1'),
#  (0.0, 'CAPN12'),
#  (0.0, 'CALCRL'),
#  (0.0, 'CA8'),
#  (0.0, 'C6orf58'),
#  (0.0, 'C6orf52'),
#  (0.0, 'C3orf67'),
#  (0.0, 'C3'),
#  (0.0, 'C2orf49'),
#  (0.0, 'C1S'),
#  (0.0, 'C1R'),
#  (0.0, 'C1QTNF1'),
#  (0.0, 'C19orf12'),
#  (0.0, 'C16orf87'),
#  (0.0, 'C15orf48'),
#  (0.0, 'C12orf76'),
#  (0.0, 'C12orf65'),
#  (0.0, 'C11orf96'),
#  (0.0, 'C10orf88'),
#  (0.0, 'BTG3'),
#  (0.0, 'BTC'),
#  (0.0, 'BSPRY'),
#  (0.0, 'BROX'),
#  (0.0, 'BLZF1'),
#  (0.0, 'BIRC3'),
#  (0.0, 'BIK'),
#  (0.0, 'BEST1'),
#  (0.0, 'BDNF-AS'),
#  (0.0, 'BCL2L1'),
#  (0.0, 'BCL2A1'),
#  (0.0, 'BATF2'),
#  (0.0, 'BACH2'),
#  (0.0, 'B4GALNT2'),
#  (0.0, 'B2M'),
#  (0.0, 'AXL'),
#  (0.0, 'AXIN2'),
#  (0.0, 'ASS1'),
#  (0.0, 'ASPH'),
#  (0.0, 'ARL13B'),
#  (0.0, 'ARHGEF28'),
#  (0.0, 'ARHGEF10'),
#  (0.0, 'ARF6'),
#  (0.0, 'AQP7P1'),
#  (0.0, 'APOPT1'),
#  (0.0, 'APOLD1'),
#  (0.0, 'APOL6'),
#  (0.0, 'APOL1'),
#  (0.0, 'AOX1'),
#  (0.0, 'ANXA3'),
#  (0.0, 'ANO9'),
#  (0.0, 'ANKRD33B'),
#  (0.0, 'ANKRD27'),
#  (0.0, 'ANKRD11'),
#  (0.0, 'ANKDD1A'),
#  (0.0, 'ANGPTL4'),
#  (0.0, 'AMIGO2'),
#  (0.0, 'ALKBH8'),
#  (0.0, 'ALDH1A3'),
#  (0.0, 'AKR1D1'),
#  (0.0, 'AKAP12'),
#  (0.0, 'AK5'),
#  (0.0, 'AJUBA'),
#  (0.0, 'AHRR'),
#  (0.0, 'AGO4'),
#  (0.0, 'AGAP11'),
#  (0.0, 'ADTRP'),
#  (0.0, 'ADRB2'),
#  (0.0, 'ADAMTS16'),
#  (0.0, 'ADAM23'),
#  (0.0, 'ACVRL1'),
#  (0.0, 'ACSL4'),
#  (0.0, 'ACOT9'),
#  (0.0, 'ACHE'),
#  (0.0, 'ABCA11P')]

# %%
selected_genes = [x[1] for x in list(sorted(zip(clf.feature_importances_, filtered_data_01.columns), reverse = True)) if x[0] > 0]
selected_genes
# Out:
# ['IL1A',
#  'NKAIN1',
#  'FSIP1',
#  'SAMD9L',
#  'EBI3',
#  'IFI16',
#  'CXCL1',
#  'NRTN',
#  'UBE2L6',
#  'FHL5',
#  'DCLK1',
#  'PHF11',
#  'THEMIS2',
#  'GBP2',
#  'GFPT2',
#  'HCN4',
#  'HERC5',
#  'TNFRSF9',
#  'PDZK1IP1',
#  'SSH1',
#  'CFB',
#  'CASP4',
#  'CLDN16',
#  'MOCOS',
#  'NMNAT1',
#  'SPATA21',
#  'KRT35',
#  'GCH1',
#  'KYNU',
#  'ICAM1',
#  'IFIT3',
#  'TLR2',
#  'FBLIM1',
#  'FHDC1',
#  'CCBE1',
#  'STX12',
#  'MT2A',
#  'SAA1',
#  'ZBTB25',
#  'CX3CL1',
#  'C22orf24',
#  'RGS17',
#  'TRANK1',
#  'GRID1',
#  'PTPRH',
#  'IFITM1',
#  'IFI44',
#  'SAMD9',
#  'FAM49A',
#  'SYTL2',
#  'SLC6A4',
#  'ADD2',
#  'PCK2',
#  'CXCL5',
#  'ANKRD26P1',
#  'CATSPER2P1',
#  'MCAM',
#  'IRF2BPL',
#  'IGFBP1',
#  'PPP1R16B',
#  'ARHGEF4',
#  'ZNF862',
#  'LOC254896',
#  'PITPNA-AS1',
#  'MOBP',
#  'IRF7',
#  'IFIT2',
#  'CCL20',
#  'GPSM3',
#  'MYPN',
#  'HBEGF',
#  'TRABD2A',
#  'ADORA2A',
#  'ZNF239',
#  'CCL5',
#  'PLIN2',
#  'JUN',
#  'BMPER',
#  'TFF1',
#  'STC2',
#  'FOXD1',
#  'RPL36A',
#  'MAP1B',
#  'NMI',
#  'PARP10',
#  'C3AR1',
#  'MB',
#  'CCL2',
#  'XAF1',
#  'HSF2BP',
#  'REEP2',
#  'PI3',
#  'DAW1',
#  'TCTE3']

# %%
results = ea.getEnrichment(selected_genes, 'GO_Biological_Process_2021')['GO_Biological_Process_2021']
results
# Out:
# Order of returned results is: Rank, Term name, P-value, Z-score, Combined score, Overlapping genes, Adjusted p-value, Old p-value, Old adjusted p-value
# [[1,
#   'response to interferon-gamma (GO:0034341)',
#   1.3336127778476142e-10,
#   29.579950289975145,
#   672.5877056730069,
#   ['IFITM1',
#    'GCH1',
#    'CCL20',
#    'KYNU',
#    'CCL5',
#    'CCL2',
#    'GBP2',
#    'CX3CL1',
#    'TLR2'],
#   1.19625066172931e-07,
#   0,
#   0],
#  [2,
#   'cytokine-mediated signaling pathway (GO:0019221)',
#   5.636790875266018e-10,
#   7.581696779261587,
#   161.46387855314202,
#   ['IFITM1',
#    'CCL20',
#    'TNFRSF9',
#    'EBI3',
#    'CXCL1',
#    'CX3CL1',
#    'CXCL5',
#    'IFIT3',
#    'IFIT2',
#    'ICAM1',
#    'IL1A',
#    'MT2A',
#    'CCL5',
#    'IRF7',
#    'SAA1',
#    'CCL2',
#    'GBP2',
#    'XAF1'],
#   2.528100707556809e-07,
#   0,
#   0],
#  [3,
#   'cellular response to interferon-gamma (GO:0071346)',
#   5.5515596247830145e-09,
#   18.71281512605042,
#   355.7154008147536,
#   ['MT2A', 'CCL20', 'CCL5', 'IRF7', 'CCL2', 'GBP2', 'CX3CL1', 'TLR2', 'ICAM1'],
#   1.6599163278101214e-06,
#   0,
#   0],
#  [4,
#   'neutrophil chemotaxis (GO:0030593)',
#   3.8032671024636885e-08,
#   25.34227330779055,
#   432.9681850211753,
#   ['CCL20', 'CCL5', 'SAA1', 'CCL2', 'CXCL1', 'CX3CL1', 'CXCL5'],
#   8.528826477274822e-06,
#   0,
#   0],
#  [5,
#   'granulocyte chemotaxis (GO:0071621)',
#   5.110585966256342e-08,
#   24.186694531522118,
#   406.0792831655491,
#   ['CCL20', 'CCL5', 'SAA1', 'CCL2', 'CXCL1', 'CX3CL1', 'CXCL5'],
#   9.168391223463877e-06,
#   0,
#   0],
#  [6,
#   'neutrophil migration (GO:1990266)',
#   7.428834128840538e-08,
#   22.8,
#   374.26910930342575,
#   ['CCL20', 'CCL5', 'SAA1', 'CCL2', 'CXCL1', 'CX3CL1', 'CXCL5'],
#   1.1106107022616604e-05,
#   0,
#   0],
#  [7,
#   'inflammatory response (GO:0006954)',
#   1.2935502184673125e-07,
#   10.652597402597403,
#   168.95770600871288,
#   ['IL1A',
#    'ADORA2A',
#    'CCL20',
#    'CCL5',
#    'C3AR1',
#    'CCL2',
#    'CXCL1',
#    'CX3CL1',
#    'CXCL5',
#    'TLR2'],
#   1.6575922085216846e-05,
#   0,
#   0],
#  [8,
#   'chemokine-mediated signaling pathway (GO:0070098)',
#   2.4639325912614405e-07,
#   27.076363636363638,
#   412.0030728264414,
#   ['CCL20', 'CCL5', 'CCL2', 'CXCL1', 'CX3CL1', 'CXCL5'],
#   2.76268441795189e-05,
#   0,
#   0],
#  [9,
#   'cellular response to chemokine (GO:1990869)',
#   3.7423195029081406e-07,
#   25.065656565656564,
#   370.93136256316365,
#   ['CCL20', 'CCL5', 'CCL2', 'CXCL1', 'CX3CL1', 'CXCL5'],
#   3.598144872904596e-05,
#   0,
#   0],
#  [10,
#   'cellular response to cytokine stimulus (GO:0071345)',
#   4.011309780272682e-07,
#   6.651425412619442,
#   97.96869747013143,
#   ['CCL20',
#    'EBI3',
#    'CXCL1',
#    'CX3CL1',
#    'ICAM1',
#    'IL1A',
#    'MT2A',
#    'IFI16',
#    'CCL5',
#    'SAA1',
#    'CCL2',
#    'GBP2',
#    'TLR2'],
#   3.598144872904596e-05,
#   0,
#   0],
#  [11,
#   'cellular response to type I interferon (GO:0071357)',
#   6.059030542472905e-07,
#   22.93567026194145,
#   328.3595746799784,
#   ['IFITM1', 'IRF7', 'GBP2', 'XAF1', 'IFIT3', 'IFIT2'],
#   4.529125330498496e-05,
#   0,
#   0],
#  [12,
#   'type I interferon signaling pathway (GO:0060337)',
#   6.059030542472905e-07,
#   22.93567026194145,
#   328.3595746799784,
#   ['IFITM1', 'IRF7', 'GBP2', 'XAF1', 'IFIT3', 'IFIT2'],
#   4.529125330498496e-05,
#   0,
#   0],
#  [13,
#   'lymphocyte migration (GO:0072676)',
#   1.1899180012658313e-06,
#   31.895666131621187,
#   435.108753482637,
#   ['CCL20', 'CCL5', 'SAA1', 'CCL2', 'CX3CL1'],
#   8.210434208734237e-05,
#   0,
#   0],
#  [14,
#   'lymphocyte chemotaxis (GO:0048247)',
#   1.9350016361623484e-06,
#   28.61855373091328,
#   376.48859003326345,
#   ['CCL20', 'CCL5', 'SAA1', 'CCL2', 'CX3CL1'],
#   0.0001239783191169733,
#   0,
#   0],
#  [15,
#   'response to tumor necrosis factor (GO:0034612)',
#   1.326158068345706e-05,
#   12.98208041958042,
#   145.79706350896578,
#   ['GCH1', 'CCL20', 'CCL5', 'CCL2', 'GBP2', 'CX3CL1'],
#   0.0007930425248707322,
#   0,
#   0],
#  [16,
#   'macrophage chemotaxis (GO:0048246)',
#   2.1449603162814258e-05,
#   72.88278388278388,
#   783.4756718388893,
#   ['CCL5', 'SAA1', 'CCL2'],
#   0.0012025183773152744,
#   0,
#   0],
#  [17,
#   'defense response to symbiont (GO:0140546)',
#   2.6229810336523823e-05,
#   11.433744221879815,
#   120.61015431298368,
#   ['IFITM1', 'IFI16', 'IRF7', 'IFIT3', 'TLR2', 'IFIT2'],
#   0.0013840082277565807,
#   0,
#   0],
#  [18,
#   'defense response to virus (GO:0051607)',
#   3.893448278058283e-05,
#   10.618647100930566,
#   107.81781645206512,
#   ['IFITM1', 'IFI16', 'IRF7', 'IFIT3', 'TLR2', 'IFIT2'],
#   0.001940235058565711,
#   0,
#   0],
#  [19,
#   'macrophage migration (GO:1905517)',
#   4.3910167237293897e-05,
#   54.65384615384615,
#   548.3619687932247,
#   ['CCL5', 'SAA1', 'CCL2'],
#   0.002003222976204444,
#   0,
#   0],
#  [20,
#   'monocyte chemotaxis (GO:0002548)',
#   4.466494930221725e-05,
#   23.237426900584797,
#   232.7535385732318,
#   ['CCL20', 'CCL5', 'CCL2', 'CX3CL1'],
#   0.002003222976204444,
#   0,
#   0],
#  [21,
#   'response to interleukin-1 (GO:0070555)',
#   5.3119781397321337e-05,
#   13.75017339436815,
#   135.3424227749377,
#   ['CCL20', 'CCL5', 'CCL2', 'GBP2', 'CX3CL1'],
#   0.002012993357482607,
#   0,
#   0],
#  [22,
#   'regulation of inflammatory response (GO:0050727)',
#   5.328694935383352e-05,
#   7.967943164096344,
#   78.40311940886603,
#   ['CCL5', 'CASP4', 'SAA1', 'NMI', 'GPSM3', 'CX3CL1', 'TLR2'],
#   0.002012993357482607,
#   0,
#   0],
#  [23,
#   'eosinophil chemotaxis (GO:0048245)',
#   5.3859354046357384e-05,
#   50.447168216398985,
#   495.85199971948134,
#   ['CCL5', 'CCL2', 'CX3CL1'],
#   0.002012993357482607,
#   0,
#   0],
#  [24,
#   'eosinophil migration (GO:0072677)',
#   5.3859354046357384e-05,
#   50.447168216398985,
#   495.85199971948134,
#   ['CCL5', 'CCL2', 'CX3CL1'],
#   0.002012993357482607,
#   0,
#   0],
#  [25,
#   'innate immune response (GO:0045087)',
#   8.906021084227534e-05,
#   6.205347255181143,
#   57.87229648205343,
#   ['IFITM1', 'GCH1', 'KYNU', 'IRF7', 'SAA1', 'PI3', 'CFB', 'TLR2'],
#   0.003149628203408871,
#   0,
#   0],
#  [26,
#   'cellular response to interleukin-1 (GO:0071347)',
#   9.129357111330061e-05,
#   9.040726052471019,
#   84.0916822241917,
#   ['IL1A', 'CCL20', 'CCL5', 'CCL2', 'GBP2', 'CX3CL1'],
#   0.003149628203408871,
#   0,
#   0],
#  [27,
#   'positive regulation of defense response (GO:0031349)',
#   9.909178599690052e-05,
#   11.968708469252144,
#   110.34507693139864,
#   ['CCL5', 'NMI', 'GPSM3', 'CX3CL1', 'TLR2'],
#   0.0032920493347859173,
#   0,
#   0],
#  [28,
#   'negative regulation of viral genome replication (GO:0045071)',
#   0.00012087841468374806,
#   17.64977777777778,
#   159.21379790798704,
#   ['PARP10', 'IFITM1', 'IFI16', 'CCL5'],
#   0.0038724263561186432,
#   0,
#   0],
#  [29,
#   'NAD biosynthetic process (GO:0009435)',
#   0.00012575499061511243,
#   36.42490842490842,
#   327.13847921682,
#   ['PARP10', 'NMNAT1', 'KYNU'],
#   0.003889731951095029,
#   0,
#   0],
#  [30,
#   'cellular response to oxygen-containing compound (GO:1901701)',
#   0.00014160157255468619,
#   5.7854558877814695,
#   51.27356387602232,
#   ['HCN4', 'IL1A', 'JUN', 'CCL2', 'CXCL1', 'CXCL5', 'TLR2', 'SSH1'],
#   0.004233887019385117,
#   0,
#   0],
#  [31,
#   'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#   0.00016149031955014893,
#   8.107886089813801,
#   70.7904833650918,
#   ['BMPER', 'CCL20', 'CCL5', 'CCL2', 'CX3CL1', 'ICAM1'],
#   0.0046728005366607605,
#   0,
#   0],
#  [32,
#   'cellular response to molecule of bacterial origin (GO:0071219)',
#   0.0002103275632626544,
#   10.110316649642492,
#   85.60247808367819,
#   ['IL1A', 'CCL2', 'CXCL1', 'CXCL5', 'TLR2'],
#   0.005895744507706281,
#   0,
#   0],
#  [33,
#   'cellular response to lipopolysaccharide (GO:0071222)',
#   0.0002564023143961114,
#   9.66829506595017,
#   79.94483864313798,
#   ['IL1A', 'CCL5', 'CCL2', 'CXCL1', 'CXCL5'],
#   0.006969481091312482,
#   0,
#   0],
#  [34,
#   'regulation of viral genome replication (GO:0045069)',
#   0.0002796301234248833,
#   13.998589065255732,
#   114.53705509322698,
#   ['PARP10', 'IFITM1', 'IFI16', 'CCL5'],
#   0.007377300609180009,
#   0,
#   0],
#  [35,
#   'interferon-gamma-mediated signaling pathway (GO:0060333)',
#   0.00029604498442361237,
#   13.779166666666667,
#   111.95571732737321,
#   ['MT2A', 'IRF7', 'GBP2', 'ICAM1'],
#   0.007497481250306519,
#   0,
#   0],
#  [36,
#   'response to interferon-beta (GO:0035456)',
#   0.0003024604907066452,
#   26.216703296703297,
#   212.44862549968624,
#   ['IFITM1', 'IFI16', 'XAF1'],
#   0.007497481250306519,
#   0,
#   0],
#  [37,
#   'cellular response to tumor necrosis factor (GO:0071356)',
#   0.00030926065358009055,
#   7.151112185686654,
#   57.79046953270837,
#   ['CCL20', 'CCL5', 'TNFRSF9', 'CCL2', 'GBP2', 'CX3CL1'],
#   0.007497481250306519,
#   0,
#   0],
#  [38,
#   'ISG15-protein conjugation (GO:0032020)',
#   0.0003238299215620844,
#   108.16304347826087,
#   869.1216502274136,
#   ['HERC5', 'UBE2L6'],
#   0.007611417699485233,
#   0,
#   0],
#  [39,
#   'negative regulation of viral process (GO:0048525)',
#   0.00033093120432544493,
#   13.36026936026936,
#   107.06385516144874,
#   ['PARP10', 'IFITM1', 'IFI16', 'CCL5'],
#   0.007611417699485233,
#   0,
#   0],
#  [40,
#   'nicotinamide nucleotide biosynthetic process (GO:0019359)',
#   0.00045197447980601367,
#   86.52608695652174,
#   666.4139574236976,
#   ['NMNAT1', 'KYNU'],
#   0.009888319716731568,
#   0,
#   0],
#  [41,
#   'regulation of natural killer cell chemotaxis (GO:2000501)',
#   0.00045197447980601367,
#   86.52608695652174,
#   666.4139574236976,
#   ['CCL5', 'CCL2'],
#   0.009888319716731568,
#   0,
#   0],
#  [42,
#   'positive regulation of response to external stimulus (GO:0032103)',
#   0.0005043814917905875,
#   8.28945161831293,
#   62.934989291251924,
#   ['CCL5', 'NMI', 'GPSM3', 'CX3CL1', 'TLR2'],
#   0.010772147574670404,
#   0,
#   0],
#  [43,
#   'regulation of type I interferon production (GO:0032479)',
#   0.0008233616499937331,
#   10.36392156862745,
#   73.60576308940142,
#   ['HERC5', 'IFI16', 'IRF7', 'UBE2L6'],
#   0.016785350001008604,
#   0,
#   0],
#  [44,
#   'positive regulation of inflammatory response (GO:0050729)',
#   0.0008233616499937331,
#   10.36392156862745,
#   73.60576308940142,
#   ['NMI', 'CX3CL1', 'GPSM3', 'TLR2'],
#   0.016785350001008604,
#   0,
#   0],
#  [45,
#   'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#   0.0009072374228325681,
#   5.781935736677116,
#   40.50307488839688,
#   ['BMPER', 'CCL20', 'CCL5', 'CCL2', 'CX3CL1', 'ICAM1'],
#   0.01806215414944584,
#   0,
#   0],
#  [46,
#   'response to lipopolysaccharide (GO:0032496)',
#   0.000926264315356197,
#   7.205603385378666,
#   50.326462679205676,
#   ['IL1A', 'GCH1', 'CCL2', 'CXCL1', 'CXCL5'],
#   0.01806215414944584,
#   0,
#   0],
#  [47,
#   'positive regulation of cytokine production (GO:0001819)',
#   0.001022872750390349,
#   4.802565180824222,
#   33.06633453399843,
#   ['IL1A', 'CCBE1', 'IFI16', 'EBI3', 'IRF7', 'SAA1', 'TLR2'],
#   0.019521635257449852,
#   0,
#   0],
#  [48,
#   'PERK-mediated unfolded protein response (GO:0036499)',
#   0.0011693273243550079,
#   48.06038647342995,
#   324.47136714038277,
#   ['IGFBP1', 'CCL2'],
#   0.021405849182580452,
#   0,
#   0],
#  [49,
#   'positive regulation of nitric-oxide synthase biosynthetic process (GO:0051770)',
#   0.0011693273243550079,
#   48.06038647342995,
#   324.47136714038277,
#   ['CCL2', 'TLR2'],
#   0.021405849182580452,
#   0,
#   0],
#  [50,
#   'positive regulation of smooth muscle cell proliferation (GO:0048661)',
#   0.0013183990059261002,
#   15.228469205213392,
#   100.98511362094811,
#   ['JUN', 'CCL5', 'CX3CL1'],
#   0.023652078166314237,
#   0,
#   0],
#  [51,
#   'negative regulation by host of viral transcription (GO:0043922)',
#   0.001648199307369968,
#   39.31818181818182,
#   251.95373669213362,
#   ['JUN', 'CCL5'],
#   0.028988917229624732,
#   0,
#   0],
#  [52,
#   'blood circulation (GO:0008015)',
#   0.0017782858455118796,
#   13.638736263736265,
#   86.36191536485507,
#   ['HCN4', 'ADORA2A', 'C3AR1'],
#   0.030675430835079922,
#   0,
#   0],
#  [53,
#   'positive regulation of MAPK cascade (GO:0043410)',
#   0.0018619897184532742,
#   4.996099050203528,
#   31.40602631154181,
#   ['BMPER', 'CCL20', 'CCL5', 'CCL2', 'CX3CL1', 'ICAM1'],
#   0.03126495153494019,
#   0,
#   0],
#  [54,
#   'regulation of nitric-oxide synthase biosynthetic process (GO:0051769)',
#   0.0019170260138480608,
#   36.039855072463766,
#   225.50066121848297,
#   ['CCL2', 'TLR2'],
#   0.03126495153494019,
#   0,
#   0],
#  [55,
#   'positive regulation of lymphocyte migration (GO:2000403)',
#   0.0019170260138480608,
#   36.039855072463766,
#   225.50066121848297,
#   ['CCL20', 'CCL5'],
#   0.03126495153494019,
#   0,
#   0],
#  [56,
#   'regulation of lymphocyte activation (GO:0051249)',
#   0.0022051992386726655,
#   33.26588628762542,
#   203.48534452549944,
#   ['THEMIS2', 'CCL5'],
#   0.034104546846368634,
#   0,
#   0],
#  [57,
#   'heterocycle biosynthetic process (GO:0018130)',
#   0.0022051992386726655,
#   33.26588628762542,
#   203.48534452549944,
#   ['GCH1', 'MOCOS'],
#   0.034104546846368634,
#   0,
#   0],
#  [58,
#   'integrated stress response signaling (GO:0140467)',
#   0.0022051992386726655,
#   33.26588628762542,
#   203.48534452549944,
#   ['IGFBP1', 'CCL2'],
#   0.034104546846368634,
#   0,
#   0],
#  [59,
#   'response to organic cyclic compound (GO:0014070)',
#   0.002834455079654809,
#   11.480046269519955,
#   67.34086737964772,
#   ['KYNU', 'CCL5', 'CCL2'],
#   0.04309332553305701,
#   0,
#   0],
#  [60,
#   'regulation of cell population proliferation (GO:0042127)',
#   0.003127902945521855,
#   3.023872679045093,
#   17.43986056298852,
#   ['IL1A',
#    'JUN',
#    'IFITM1',
#    'TNFRSF9',
#    'CXCL1',
#    'NMI',
#    'CX3CL1',
#    'CXCL5',
#    'IFIT3',
#    'HBEGF'],
#   0.04676214903555173,
#   0,
#   0],
#  [61,
#   'regulation of innate immune response (GO:0045088)',
#   0.0034047053494091115,
#   10.725094577553595,
#   60.94638896058672,
#   ['IFI16', 'CCL5', 'NMI'],
#   0.05006591308885202,
#   0,
#   0],
#  [62,
#   'positive regulation of macrophage migration (GO:1905523)',
#   0.0035476988486272047,
#   25.433503836317136,
#   143.48199529383507,
#   ['CCL5', 'CX3CL1'],
#   0.051327191406751654,
#   0,
#   0],
#  [63,
#   'regulation of T cell migration (GO:2000404)',
#   0.003929871828835359,
#   24.019323671497585,
#   133.04659989721253,
#   ['CCL20', 'CCL5'],
#   0.05507960985102058,
#   0,
#   0],
#  [64,
#   'lipopolysaccharide-mediated signaling pathway (GO:0031663)',
#   0.003929871828835359,
#   24.019323671497585,
#   133.04659989721253,
#   ['CCL5', 'CCL2'],
#   0.05507960985102058,
#   0,
#   0],
#  [65,
#   'cell chemotaxis (GO:0060326)',
#   0.00420986393551384,
#   9.91008991008991,
#   54.21141210345841,
#   ['CCL20', 'CX3CL1', 'HBEGF'],
#   0.058096122310091,
#   0,
#   0],
#  [66,
#   'apoptotic process (GO:0006915)',
#   0.004697707369715485,
#   4.892114944814557,
#   26.225066083456596,
#   ['IL1A', 'ADORA2A', 'CASP4', 'TLR2', 'IFIT2'],
#   0.06384611379749683,
#   0,
#   0],
#  [67,
#   'response to copper ion (GO:0046688)',
#   0.0051852594222442485,
#   20.58488612836439,
#   108.31634113357939,
#   ['IL1A', 'MT2A'],
#   0.0694205627127327,
#   0,
#   0],
#  [68,
#   'positive regulation of hydrolase activity (GO:0051345)',
#   0.00537149602382962,
#   6.057011494252873,
#   31.657871979724053,
#   ['CCL20', 'CCL5', 'CCL2', 'CX3CL1'],
#   0.06947498433694002,
#   0,
#   0],
#  [69,
#   'regulation of cytokine production (GO:0001817)',
#   0.00549913476914464,
#   6.015220700152207,
#   31.29818288982711,
#   ['IL1A', 'IFI16', 'IRF7', 'SAA1'],
#   0.06947498433694002,
#   0,
#   0],
#  [70,
#   'cellular response to organic cyclic compound (GO:0071407)',
#   0.00549913476914464,
#   6.015220700152207,
#   31.29818288982711,
#   ['HCN4', 'CCL5', 'CCL2', 'SSH1'],
#   0.06947498433694002,
#   0,
#   0],
#  [71,
#   'response to cytokine (GO:0034097)',
#   0.00549913476914464,
#   6.015220700152207,
#   31.29818288982711,
#   ['IFITM1', 'GCH1', 'KYNU', 'XAF1'],
#   0.06947498433694002,
#   0,
#   0],
#  [72,
#   'protein kinase B signaling (GO:0043491)',
#   0.005639427655241041,
#   19.64822134387352,
#   101.73795368654676,
#   ['CCL5', 'CCL2'],
#   0.07025786953821131,
#   0,
#   0],
#  [73,
#   'positive regulation of type I interferon production (GO:0032481)',
#   0.0057211732839192704,
#   8.835164835164836,
#   45.62109258842689,
#   ['IFI16', 'IRF7', 'TLR2'],
#   0.07029989637911761,
#   0,
#   0],
#  [74,
#   'receptor signaling pathway via STAT (GO:0097696)',
#   0.006111159851364195,
#   18.793005671077506,
#   95.79995291250643,
#   ['CCL2', 'NMI'],
#   0.07212776824570635,
#   0,
#   0],
#  [75,
#   'positive regulation of T cell migration (GO:2000406)',
#   0.006111159851364195,
#   18.793005671077506,
#   95.79995291250643,
#   ['CCL20', 'CCL5'],
#   0.07212776824570635,
#   0,
#   0],
#  [76,
#   'positive regulation of vascular endothelial growth factor production (GO:0010575)',
#   0.006111159851364195,
#   18.793005671077506,
#   95.79995291250643,
#   ['CCBE1', 'IL1A'],
#   0.07212776824570635,
#   0,
#   0],
#  [77,
#   'endothelial cell development (GO:0001885)',
#   0.006600284483977989,
#   18.009057971014492,
#   90.41704232490787,
#   ['PPP1R16B', 'ICAM1'],
#   0.07688902833932801,
#   0,
#   0],
#  [78,
#   'cellular response to cadmium ion (GO:0071276)',
#   0.007106631219173753,
#   17.28782608695652,
#   85.51815531993533,
#   ['MT2A', 'JUN'],
#   0.07968310254498571,
#   0,
#   0],
#  [79,
#   'regulation of toll-like receptor signaling pathway (GO:0034121)',
#   0.007106631219173753,
#   17.28782608695652,
#   85.51815531993533,
#   ['IRF7', 'TLR2'],
#   0.07968310254498571,
#   0,
#   0],
#  [80,
#   'regulation of vascular endothelial growth factor production (GO:0010574)',
#   0.007106631219173753,
#   17.28782608695652,
#   85.51815531993533,
#   ['CCBE1', 'IL1A'],
#   0.07968310254498571,
#   0,
#   0],
#  [81,
#   'negative regulation of defense response (GO:0031348)',
#   0.007519681311821682,
#   7.969981238273921,
#   38.97505347051986,
#   ['IFI16', 'SAA1', 'NMI'],
#   0.08327350786054381,
#   0,
#   0],
#  [82,
#   'leukocyte cell-cell adhesion (GO:0007159)',
#   0.007630030913614265,
#   16.622073578595316,
#   81.04363548183322,
#   ['CCL5', 'ICAM1'],
#   0.08346509426234142,
#   0,
#   0],
#  [83,
#   'regulation of response to biotic stimulus (GO:0002831)',
#   0.008170315601077824,
#   16.005636070853463,
#   76.94305785437658,
#   ['HERC5', 'CX3CL1'],
#   0.08622085993137421,
#   0,
#   0],
#  [84,
#   'establishment of endothelial barrier (GO:0061028)',
#   0.008170315601077824,
#   16.005636070853463,
#   76.94305785437658,
#   ['PPP1R16B', 'ICAM1'],
#   0.08622085993137421,
#   0,
#   0],
#  [85,
#   'response to cadmium ion (GO:0046686)',
#   0.008170315601077824,
#   16.005636070853463,
#   76.94305785437658,
#   ['MT2A', 'JUN'],
#   0.08622085993137421,
#   0,
#   0],
#  [86,
#   'negative regulation of binding (GO:0051100)',
#   0.008270702258875568,
#   7.687524240465417,
#   36.86195438552468,
#   ['JUN', 'IFI16', 'IFIT2'],
#   0.08626534797920214,
#   0,
#   0],
#  [87,
#   'negative regulation of cell population proliferation (GO:0008285)',
#   0.008958746183003248,
#   3.5704971971728003,
#   16.835340585107375,
#   ['PARP10', 'IL1A', 'IFITM1', 'CXCL1', 'NMI', 'IFIT3'],
#   0.0923677623695852,
#   0,
#   0],
#  [88,
#   'receptor signaling pathway via JAK-STAT (GO:0007259)',
#   0.00930087394698537,
#   14.900299850074962,
#   69.69834155839186,
#   ['CCL2', 'NMI'],
#   0.09269871033828753,
#   0,
#   0],
#  [89,
#   'negative regulation of DNA binding (GO:0043392)',
#   0.00930087394698537,
#   14.900299850074962,
#   69.69834155839186,
#   ['JUN', 'IFI16'],
#   0.09269871033828753,
#   0,
#   0],
#  [90,
#   'negative regulation of response to biotic stimulus (GO:0002832)',
#   0.00930087394698537,
#   14.900299850074962,
#   69.69834155839186,
#   ['IFI16', 'NMI'],
#   0.09269871033828753,
#   0,
#   0],
#  [91,
#   'regulation of cellular biosynthetic process (GO:0031326)',
#   0.009890817509289765,
#   14.402898550724638,
#   66.4859182031573,
#   ['CCL5', 'STC2'],
#   0.0964354707155752,
#   0,
#   0],
#  [92,
#   'modulation by host of symbiont process (GO:0051851)',
#   0.009890817509289765,
#   14.402898550724638,
#   66.4859182031573,
#   ['JUN', 'CCL5'],
#   0.0964354707155752,
#   0,
#   0],
#  [93,
#   'regulation of immune response (GO:0050776)',
#   0.010130883864957637,
#   5.011047619047619,
#   23.01156606999504,
#   ['HERC5', 'IFITM1', 'IRF7', 'ICAM1'],
#   0.09771400889104301,
#   0,
#   0],
#  [94,
#   'regulation of sprouting angiogenesis (GO:1903670)',
#   0.010496985856888533,
#   13.937587657784011,
#   63.50894747195799,
#   ['PPP1R16B', 'BMPER'],
#   0.10016804588967035,
#   0,
#   0],
#  [95,
#   'organic cyclic compound biosynthetic process (GO:1901362)',
#   0.011119216815215943,
#   13.501358695652174,
#   60.74369859051535,
#   ['GCH1', 'MOCOS'],
#   0.10498881561314423,
#   0,
#   0],
#  [96,
#   'cellular response to amyloid-beta (GO:1904646)',
#   0.011757349349970485,
#   13.091567852437418,
#   58.16945915571359,
#   ['CASP4', 'ICAM1'],
#   0.10985773298878672,
#   0,
#   0],
#  [97,
#   'regulation of GTPase activity (GO:0043087)',
#   0.012177042860321875,
#   4.737777777777778,
#   20.88508542064,
#   ['CCL20', 'CCL5', 'CCL2', 'CX3CL1'],
#   0.11132867529832005,
#   0,
#   0],
#  [98,
#   'positive regulation of innate immune response (GO:0045089)',
#   0.012411223556111487,
#   12.705882352941176,
#   55.768075499740505,
#   ['CCL5', 'NMI'],
#   0.11132867529832005,
#   0,
#   0],
#  [99,
#   'positive regulation of interferon-beta production (GO:0032728)',
#   0.012411223556111487,
#   12.705882352941176,
#   55.768075499740505,
#   ['IRF7', 'TLR2'],
#   0.11132867529832005,
#   0,
#   0],
#  [100,
#   'macrophage activation (GO:0042116)',
#   0.012411223556111487,
#   12.705882352941176,
#   55.768075499740505,
#   ['NMI', 'CX3CL1'],
#   0.11132867529832005,
#   0,
#   0],
#  [101,
#   'cellular metal ion homeostasis (GO:0006875)',
#   0.013007491824609675,
#   6.464476117941464,
#   28.07024079748959,
#   ['STC2', 'CCL5', 'CLDN16'],
#   0.11391621887216145,
#   0,
#   0],
#  [102,
#   'positive regulation of calcium ion transport (GO:0051928)',
#   0.013080680650872497,
#   12.34223602484472,
#   53.52357397384211,
#   ['CCL5', 'CCL2'],
#   0.11391621887216145,
#   0,
#   0],
#  [103,
#   'positive regulation of signaling receptor activity (GO:2000273)',
#   0.013080680650872497,
#   12.34223602484472,
#   53.52357397384211,
#   ['CCL2', 'HBEGF'],
#   0.11391621887216145,
#   0,
#   0],
#  [104,
#   'negative regulation of innate immune response (GO:0045824)',
#   0.013765562969598598,
#   11.998792270531402,
#   51.42184708357683,
#   ['IFI16', 'NMI'],
#   0.1187279806127879,
#   0,
#   0],
#  [105,
#   'regulation of nitric-oxide synthase activity (GO:0050999)',
#   0.014465713956762766,
#   11.673913043478262,
#   49.45039194640452,
#   ['IL1A', 'GCH1'],
#   0.12357852780205905,
#   0,
#   0],
#  [106,
#   'regulation of interleukin-6 production (GO:0032675)',
#   0.015109203869631648,
#   6.1001335113484645,
#   25.574512017464105,
#   ['IL1A', 'CX3CL1', 'TLR2'],
#   0.12785807425527912,
#   0,
#   0],
#  [107,
#   'cellular divalent inorganic cation homeostasis (GO:0072503)',
#   0.015477038787337694,
#   6.043345543345543,
#   25.191067795699258,
#   ['MT2A', 'STC2', 'CCL5'],
#   0.12974676441347582,
#   0,
#   0],
#  [108,
#   'translesion synthesis (GO:0019985)',
#   0.01665622989862723,
#   10.796739130434782,
#   44.212333249908134,
#   ['PARP10', 'UBE2L6'],
#   0.13833924276915394,
#   0,
#   0],
#  [109,
#   'negative regulation of type I interferon production (GO:0032480)',
#   0.017415911980779488,
#   10.53287380699894,
#   42.66204670923194,
#   ['HERC5', 'UBE2L6'],
#   0.14010199121475655,
#   0,
#   0],
#  [110,
#   'DNA synthesis involved in DNA repair (GO:0000731)',
#   0.017415911980779488,
#   10.53287380699894,
#   42.66204670923194,
#   ['PARP10', 'UBE2L6'],
#   0.14010199121475655,
#   0,
#   0],
#  [111,
#   'regulation of endothelial cell apoptotic process (GO:2000351)',
#   0.01819009637610396,
#   10.281573498964804,
#   41.197010536699175,
#   ['CCL2', 'ICAM1'],
#   0.14010199121475655,
#   0,
#   0],
#  [112,
#   'response to amyloid-beta (GO:1904645)',
#   0.01819009637610396,
#   10.281573498964804,
#   41.197010536699175,
#   ['CASP4', 'ICAM1'],
#   0.14010199121475655,
#   0,
#   0],
#  [113,
#   'negative regulation of response to external stimulus (GO:0032102)',
#   0.018193231857994426,
#   5.67348303870043,
#   22.73197643285215,
#   ['IFI16', 'SAA1', 'NMI'],
#   0.14010199121475655,
#   0,
#   0],
#  [114,
#   'positive regulation of GTPase activity (GO:0043547)',
#   0.01839806605874798,
#   4.168465608465609,
#   16.655144878594736,
#   ['CCL20', 'CCL5', 'CCL2', 'CX3CL1'],
#   0.14010199121475655,
#   0,
#   0],
#  [115,
#   'nervous system development (GO:0007399)',
#   0.018862665666369818,
#   3.0094310451453308,
#   11.949158647513364,
#   ['ADORA2A', 'MOBP', 'CXCL1', 'NRTN', 'DCLK1', 'IRF2BPL'],
#   0.14010199121475655,
#   0,
#   0],
#  [116,
#   'positive regulation of response to biotic stimulus (GO:0002833)',
#   0.018978633042899946,
#   10.04196157735086,
#   39.81076931220625,
#   ['CCL5', 'NMI'],
#   0.14010199121475655,
#   0,
#   0],
#  [117,
#   'postreplication repair (GO:0006301)',
#   0.019781373014179343,
#   9.813241106719367,
#   38.497487555319324,
#   ['PARP10', 'UBE2L6'],
#   0.14010199121475655,
#   0,
#   0],
#  [118,
#   'cellular response to lipid (GO:0071396)',
#   0.019840364122635554,
#   4.0704909560723515,
#   15.956474440940049,
#   ['IL1A', 'CCL2', 'CXCL1', 'CXCL5'],
#   0.14010199121475655,
#   0,
#   0],
#  [119,
#   'regulation of DNA binding (GO:0051101)',
#   0.020598168374574264,
#   9.594685990338164,
#   37.25187803675723,
#   ['JUN', 'IFI16'],
#   0.14010199121475655,
#   0,
#   0],
#  [120,
#   'positive regulation of cell-cell adhesion (GO:0022409)',
#   0.020598168374574264,
#   9.594685990338164,
#   37.25187803675723,
#   ['CCL5', 'CX3CL1'],
#   0.14010199121475655,
#   0,
#   0],
#  [121,
#   'regulation of T cell activation (GO:0050863)',
#   0.020598168374574264,
#   9.594685990338164,
#   37.25187803675723,
#   ['CCL5', 'CCL2'],
#   0.14010199121475655,
#   0,
#   0],
#  [122,
#   'regulation of tumor necrosis factor production (GO:0032680)',
#   0.020719197613640977,
#   5.390518572336754,
#   20.89739417347143,
#   ['IL1A', 'CX3CL1', 'TLR2'],
#   0.14010199121475655,
#   0,
#   0],
#  [123,
#   'regulation of protein secretion (GO:0050708)',
#   0.02115800004221252,
#   5.346063772293281,
#   20.61301691989344,
#   ['IL1A', 'CCL5', 'SAA1'],
#   0.14010199121475655,
#   0,
#   0],
#  [124,
#   'cellular protein modification process (GO:0006464)',
#   0.022068751300069578,
#   2.215693173821253,
#   8.449751178803925,
#   ['HERC5',
#    'IGFBP1',
#    'PARP10',
#    'STC2',
#    'CCL2',
#    'UBE2L6',
#    'PI3',
#    'PTPRH',
#    'DCLK1',
#    'SSH1'],
#   0.14010199121475655,
#   0,
#   0],
#  [125,
#   'regulation of interferon-beta production (GO:0032648)',
#   0.022273338845784817,
#   9.185476410730805,
#   34.94490389272714,
#   ['IRF7', 'TLR2'],
#   0.14010199121475655,
#   0,
#   0],
#  [126,
#   'regulation of smooth muscle cell proliferation (GO:0048660)',
#   0.022273338845784817,
#   9.185476410730805,
#   34.94490389272714,
#   ['CCL5', 'CX3CL1'],
#   0.14010199121475655,
#   0,
#   0],
#  [127,
#   'regulation of complement activation (GO:0030449)',
#   0.023131423352716708,
#   8.993659420289855,
#   33.87518721331595,
#   ['C3AR1', 'CFB'],
#   0.14010199121475655,
#   0,
#   0],
#  [128,
#   'receptor-mediated virion attachment to host cell (GO:0046813)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['ICAM1'],
#   0.14010199121475655,
#   0,
#   0],
#  [129,
#   'negative regulation of organ growth (GO:0046621)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['SLC6A4'],
#   0.14010199121475655,
#   0,
#   0],
#  [130,
#   'negative regulation of protein polyubiquitination (GO:1902915)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['PARP10'],
#   0.14010199121475655,
#   0,
#   0],
#  [131,
#   'cellular response to cGMP (GO:0071321)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['HCN4'],
#   0.14010199121475655,
#   0,
#   0],
#  [132,
#   'cellular response to erythropoietin (GO:0036018)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['MT2A'],
#   0.14010199121475655,
#   0,
#   0],
#  [133,
#   'negative regulation of synapse organization (GO:1905809)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['TLR2'],
#   0.14010199121475655,
#   0,
#   0],
#  [134,
#   'regulation of hippocampal neuron apoptotic process (GO:0110089)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['CX3CL1'],
#   0.14010199121475655,
#   0,
#   0],
#  [135,
#   'regulation of hormone metabolic process (GO:0032350)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['STC2'],
#   0.14010199121475655,
#   0,
#   0],
#  [136,
#   'negative regulation of vascular endothelial cell proliferation (GO:1905563)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['CCL2'],
#   0.14010199121475655,
#   0,
#   0],
#  [137,
#   'regulation of interleukin-1 alpha production (GO:0032650)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['CX3CL1'],
#   0.14010199121475655,
#   0,
#   0],
#  [138,
#   'regulation of kidney development (GO:0090183)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['FOXD1'],
#   0.14010199121475655,
#   0,
#   0],
#  [139,
#   'dopamine biosynthetic process (GO:0042416)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['GCH1'],
#   0.14010199121475655,
#   0,
#   0],
#  [140,
#   'glycerol biosynthetic process (GO:0006114)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['PCK2'],
#   0.14010199121475655,
#   0,
#   0],
#  [141,
#   'response to cGMP (GO:0070305)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['HCN4'],
#   0.14010199121475655,
#   0,
#   0],
#  [142,
#   'positive regulation of interleukin-18 production (GO:0032741)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['TLR2'],
#   0.14010199121475655,
#   0,
#   0],
#  [143,
#   'SA node cell to atrial cardiac muscle cell signaling (GO:0086018)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['HCN4'],
#   0.14010199121475655,
#   0,
#   0],
#  [144,
#   'positive regulation of natural killer cell chemotaxis (GO:2000503)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['CCL5'],
#   0.14010199121475655,
#   0,
#   0],
#  [145,
#   'serotonin transport (GO:0006837)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['SLC6A4'],
#   0.14010199121475655,
#   0,
#   0],
#  [146,
#   'serotonin uptake (GO:0051610)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['SLC6A4'],
#   0.14010199121475655,
#   0,
#   0],
#  [147,
#   'T cell extravasation (GO:0072683)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['CCL2'],
#   0.14010199121475655,
#   0,
#   0],
#  [148,
#   'membrane depolarization during SA node cell action potential (GO:0086046)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['HCN4'],
#   0.14010199121475655,
#   0,
#   0],
#  [149,
#   'tryptophan catabolic process to kynurenine (GO:0019441)',
#   0.023282278577421368,
#   53.5,
#   201.1633589371276,
#   ['KYNU'],
#   0.14010199121475655,
#   0,
#   0],
#  [150,
#   'regulation of response to external stimulus (GO:0032101)',
#   0.023428426624541226,
#   5.134290905944449,
#   19.27312780294187,
#   ['HERC5', 'CASP4', 'CX3CL1'],
#   0.14010199121475655,
#   0,
#   0],
#  [151,
#   'sensory perception (GO:0007600)',
#   0.024002982032252727,
#   8.809671694764862,
#   32.85635073640704,
#   ['ADORA2A', 'CCL2'],
#   0.14046608365927363,
#   0,
#   0],
#  [152,
#   'sprouting angiogenesis (GO:0002040)',
#   0.024887872153036093,
#   8.63304347826087,
#   31.885063989274137,
#   ['CCBE1', 'BMPER'],
#   0.14046608365927363,
#   0,
#   0],
#  [153,
#   'regulation of immune effector process (GO:0002697)',
#   0.0257859520097423,
#   8.463341858482524,
#   30.958273416173974,
#   ['C3AR1', 'CFB'],
#   0.14046608365927363,
#   0,
#   0],
#  [154,
#   'positive regulation of NIK/NF-kappaB signaling (GO:1901224)',
#   0.0257859520097423,
#   8.463341858482524,
#   30.958273416173974,
#   ['NMI', 'TLR2'],
#   0.14046608365927363,
#   0,
#   0],
#  [155,
#   'regulation of humoral immune response (GO:0002920)',
#   0.02669708090688378,
#   8.300167224080267,
#   30.07317459219205,
#   ['C3AR1', 'CFB'],
#   0.14046608365927363,
#   0,
#   0],
#  [156,
#   'pteridine-containing compound biosynthetic process (GO:0042559)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['GCH1'],
#   0.14046608365927363,
#   0,
#   0],
#  [157,
#   'blood vessel endothelial cell proliferation involved in sprouting angiogenesis (GO:0002043)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['BMPER'],
#   0.14046608365927363,
#   0,
#   0],
#  [158,
#   'negative regulation of myeloid cell apoptotic process (GO:0033033)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['IRF7'],
#   0.14046608365927363,
#   0,
#   0],
#  [159,
#   'negative regulation of neuron migration (GO:2001223)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CX3CL1'],
#   0.14046608365927363,
#   0,
#   0],
#  [160,
#   'cell junction disassembly (GO:0150146)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CX3CL1'],
#   0.14046608365927363,
#   0,
#   0],
#  [161,
#   'cellular response to bacterial lipopeptide (GO:0071221)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['TLR2'],
#   0.14046608365927363,
#   0,
#   0],
#  [162,
#   'cellular response to lipoteichoic acid (GO:0071223)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['TLR2'],
#   0.14046608365927363,
#   0,
#   0],
#  [163,
#   'regulation of glutamate receptor signaling pathway (GO:1900449)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CX3CL1'],
#   0.14046608365927363,
#   0,
#   0],
#  [164,
#   'regulation of hormone biosynthetic process (GO:0046885)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['STC2'],
#   0.14046608365927363,
#   0,
#   0],
#  [165,
#   'regulation of immature T cell proliferation in thymus (GO:0033084)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['IL1A'],
#   0.14046608365927363,
#   0,
#   0],
#  [166,
#   'regulation of macrophage apoptotic process (GO:2000109)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['IRF7'],
#   0.14046608365927363,
#   0,
#   0],
#  [167,
#   'regulation of protein depolymerization (GO:1901879)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['MAP1B'],
#   0.14046608365927363,
#   0,
#   0],
#  [168,
#   'regulation of response to reactive oxygen species (GO:1901031)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['GCH1'],
#   0.14046608365927363,
#   0,
#   0],
#  [169,
#   'regulation of superoxide metabolic process (GO:0090322)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['GCH1'],
#   0.14046608365927363,
#   0,
#   0],
#  [170,
#   'positive regulation of cell-cell adhesion mediated by integrin (GO:0033634)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CCL5'],
#   0.14046608365927363,
#   0,
#   0],
#  [171,
#   'hepatocyte differentiation (GO:0070365)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['PCK2'],
#   0.14046608365927363,
#   0,
#   0],
#  [172,
#   'positive regulation of I-kappaB phosphorylation (GO:1903721)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CX3CL1'],
#   0.14046608365927363,
#   0,
#   0],
#  [173,
#   'response to lipoteichoic acid (GO:0070391)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['TLR2'],
#   0.14046608365927363,
#   0,
#   0],
#  [174,
#   'positive regulation of kidney development (GO:0090184)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['FOXD1'],
#   0.14046608365927363,
#   0,
#   0],
#  [175,
#   'positive regulation of microglial cell migration (GO:1904141)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CX3CL1'],
#   0.14046608365927363,
#   0,
#   0],
#  [176,
#   'positive regulation of vascular endothelial growth factor signaling pathway (GO:1900748)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CCBE1'],
#   0.14046608365927363,
#   0,
#   0],
#  [177,
#   'venous blood vessel morphogenesis (GO:0048845)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['CCBE1'],
#   0.14046608365927363,
#   0,
#   0],
#  [178,
#   'molybdopterin cofactor biosynthetic process (GO:0032324)',
#   0.027873983156466782,
#   42.79784946236559,
#   153.2189343652742,
#   ['MOCOS'],
#   0.14046608365927363,
#   0,
#   0],
#  [179,
#   'cellular response to peptide (GO:1901653)',
#   0.02950736994340076,
#   7.846245059288537,
#   27.64322537448633,
#   ['CASP4', 'ICAM1'],
#   0.1478665410012876,
#   0,
#   0],
#  [180,
#   'regulation of chromatin assembly or disassembly (GO:0001672)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['PARP10'],
#   0.14848247643313864,
#   0,
#   0],
#  [181,
#   'cellular cation homeostasis (GO:0030003)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CLDN16'],
#   0.14848247643313864,
#   0,
#   0],
#  [182,
#   'negative regulation of protein K63-linked ubiquitination (GO:1900045)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['PARP10'],
#   0.14848247643313864,
#   0,
#   0],
#  [183,
#   'regulation of glial cell apoptotic process (GO:0034350)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CCL2'],
#   0.14848247643313864,
#   0,
#   0],
#  [184,
#   'negative regulation of T cell apoptotic process (GO:0070233)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CCL5'],
#   0.14848247643313864,
#   0,
#   0],
#  [185,
#   'regulation of I-kappaB phosphorylation (GO:1903719)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CX3CL1'],
#   0.14848247643313864,
#   0,
#   0],
#  [186,
#   'complement activation, alternative pathway (GO:0006957)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CFB'],
#   0.14848247643313864,
#   0,
#   0],
#  [187,
#   'regulation of microglial cell migration (GO:1904139)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CX3CL1'],
#   0.14848247643313864,
#   0,
#   0],
#  [188,
#   'oxygen transport (GO:0015671)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['MB'],
#   0.14848247643313864,
#   0,
#   0],
#  [189,
#   'positive regulation of activation of Janus kinase activity (GO:0010536)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CCL5'],
#   0.14848247643313864,
#   0,
#   0],
#  [190,
#   'glial cell migration (GO:0008347)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CCL2'],
#   0.14848247643313864,
#   0,
#   0],
#  [191,
#   'response to host defenses (GO:0052200)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['TLR2'],
#   0.14848247643313864,
#   0,
#   0],
#  [192,
#   'positive regulation of lymphocyte apoptotic process (GO:0070230)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['CCL5'],
#   0.14848247643313864,
#   0,
#   0],
#  [193,
#   'SA node cell action potential (GO:0086015)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['HCN4'],
#   0.14848247643313864,
#   0,
#   0],
#  [194,
#   'sinoatrial node development (GO:0003163)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['HCN4'],
#   0.14848247643313864,
#   0,
#   0],
#  [195,
#   'vascular wound healing (GO:0061042)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['MCAM'],
#   0.14848247643313864,
#   0,
#   0],
#  [196,
#   'modulation by symbiont of host defense response (GO:0052031)',
#   0.03244433152831123,
#   35.66308243727599,
#   122.26123249735372,
#   ['TLR2'],
#   0.14848247643313864,
#   0,
#   0],
#  [197,
#   'positive regulation of interleukin-1 production (GO:0032732)',
#   0.03443932332146961,
#   7.190579710144927,
#   24.22187220688137,
#   ['IFI16', 'SAA1'],
#   0.1508322690767451,
#   0,
#   0],
#  [198,
#   'amyloid fibril formation (GO:1990000)',
#   0.035461726299078726,
#   7.072344975053457,
#   23.616690744660367,
#   ['SAA1', 'UBE2L6'],
#   0.1508322690767451,
#   0,
#   0],
#  [199,
#   'antimicrobial humoral immune response mediated by antimicrobial peptide (GO:0061844)',
#   0.03649582569857722,
#   6.957924263674614,
#   23.03460758568978,
#   ['CXCL1', 'CXCL5'],
#   0.1508322690767451,
#   0,
#   0],
#  [200,
#   'regulation of activation of Janus kinase activity (GO:0010533)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CCL5'],
#   0.1508322690767451,
#   0,
#   0],
#  [201,
#   'regulation of alpha-beta T cell proliferation (GO:0046640)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['EBI3'],
#   0.1508322690767451,
#   0,
#   0],
#  [202,
#   'aromatic compound biosynthetic process (GO:0019438)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['GCH1'],
#   0.1508322690767451,
#   0,
#   0],
#  [203,
#   'regulation of apoptotic cell clearance (GO:2000425)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CCL2'],
#   0.1508322690767451,
#   0,
#   0],
#  [204,
#   'negative regulation of glial cell apoptotic process (GO:0034351)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CCL2'],
#   0.1508322690767451,
#   0,
#   0],
#  [205,
#   'benzene-containing compound metabolic process (GO:0042537)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['KYNU'],
#   0.1508322690767451,
#   0,
#   0],
#  [206,
#   'regulation of cardiac muscle cell action potential involved in regulation of contraction (GO:0098909)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['HCN4'],
#   0.1508322690767451,
#   0,
#   0],
#  [207,
#   'negative regulation of microglial cell activation (GO:1903979)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CX3CL1'],
#   0.1508322690767451,
#   0,
#   0],
#  [208,
#   'regulation of interleukin-18 production (GO:0032661)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['TLR2'],
#   0.1508322690767451,
#   0,
#   0],
#  [209,
#   'neurotransmitter reuptake (GO:0098810)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['SLC6A4'],
#   0.1508322690767451,
#   0,
#   0],
#  [210,
#   'regulation of MyD88-independent toll-like receptor signaling pathway (GO:0034127)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['IRF7'],
#   0.1508322690767451,
#   0,
#   0],
#  [211,
#   'regulation of myeloid leukocyte differentiation (GO:0002761)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['IRF7'],
#   0.1508322690767451,
#   0,
#   0],
#  [212,
#   'regulation of protein K63-linked ubiquitination (GO:1900044)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['PARP10'],
#   0.1508322690767451,
#   0,
#   0],
#  [213,
#   'endosomal vesicle fusion (GO:0034058)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['SAMD9'],
#   0.1508322690767451,
#   0,
#   0],
#  [214,
#   'positive regulation of apoptotic cell clearance (GO:2000427)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CCL2'],
#   0.1508322690767451,
#   0,
#   0],
#  [215,
#   'positive regulation of glial cell migration (GO:1903977)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CX3CL1'],
#   0.1508322690767451,
#   0,
#   0],
#  [216,
#   'positive regulation of homotypic cell-cell adhesion (GO:0034112)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CCL5'],
#   0.1508322690767451,
#   0,
#   0],
#  [217,
#   'integrin activation (GO:0033622)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CX3CL1'],
#   0.1508322690767451,
#   0,
#   0],
#  [218,
#   'short-chain fatty acid catabolic process (GO:0019626)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['PCK2'],
#   0.1508322690767451,
#   0,
#   0],
#  [219,
#   'venous blood vessel development (GO:0060841)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['CCBE1'],
#   0.1508322690767451,
#   0,
#   0],
#  [220,
#   'monoamine transport (GO:0015844)',
#   0.03699342162417383,
#   30.566820276497698,
#   100.7792703363177,
#   ['SLC6A4'],
#   0.1508322690767451,
#   0,
#   0],
#  [221,
#   'positive regulation of T cell proliferation (GO:0042102)',
#   0.03859859485749233,
#   6.739809782608695,
#   21.93497652529572,
#   ['CCL5', 'EBI3'],
#   0.15666488500982179,
#   0,
#   0],
#  [222,
#   'regulation of cellular extravasation (GO:0002691)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['ICAM1'],
#   0.15984829127144096,
#   0,
#   0],
#  [223,
#   'regulation of cellular response to oxidative stress (GO:1900407)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['GCH1'],
#   0.15984829127144096,
#   0,
#   0],
#  [224,
#   'cellular response to leptin stimulus (GO:0044320)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['EBI3'],
#   0.15984829127144096,
#   0,
#   0],
#  [225,
#   'regulation of leukocyte mediated cytotoxicity (GO:0001910)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['ICAM1'],
#   0.15984829127144096,
#   0,
#   0],
#  [226,
#   'positive regulation of blood vessel endothelial cell proliferation involved in sprouting angiogenesis (GO:1903589)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['PPP1R16B'],
#   0.15984829127144096,
#   0,
#   0],
#  [227,
#   'glomerular filtration (GO:0003094)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['MCAM'],
#   0.15984829127144096,
#   0,
#   0],
#  [228,
#   'response to vitamin (GO:0033273)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['KYNU'],
#   0.15984829127144096,
#   0,
#   0],
#  [229,
#   'kynurenine metabolic process (GO:0070189)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['KYNU'],
#   0.15984829127144096,
#   0,
#   0],
#  [230,
#   'synapse pruning (GO:0098883)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['CX3CL1'],
#   0.15984829127144096,
#   0,
#   0],
#  [231,
#   'T-helper 1 type immune response (GO:0042088)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['EBI3'],
#   0.15984829127144096,
#   0,
#   0],
#  [232,
#   'positive regulation of sequestering of triglyceride (GO:0010890)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['PLIN2'],
#   0.15984829127144096,
#   0,
#   0],
#  [233,
#   'positive regulation of tumor necrosis factor-mediated signaling pathway (GO:1903265)',
#   0.04152135102145568,
#   26.74462365591398,
#   85.08929057374515,
#   ['CASP4'],
#   0.15984829127144096,
#   0,
#   0],
#  [234,
#   'defense response to Gram-positive bacterium (GO:0050830)',
#   0.04293883460255329,
#   6.342071611253197,
#   19.964705883356594,
#   ['GBP2', 'TLR2'],
#   0.16165459986901218,
#   0,
#   0],
#  [235,
#   'negative regulation of neuron apoptotic process (GO:0043524)',
#   0.04405122228301113,
#   6.249842470069313,
#   19.514521749182098,
#   ['CCL2', 'CX3CL1'],
#   0.16165459986901218,
#   0,
#   0],
#  [236,
#   'response to metal ion (GO:0010038)',
#   0.04405122228301113,
#   6.249842470069313,
#   19.514521749182098,
#   ['IL1A', 'MT2A'],
#   0.16165459986901218,
#   0,
#   0],
#  [237,
#   'positive regulation of protein secretion (GO:0050714)',
#   0.0451742926988683,
#   6.160248447204969,
#   19.07968843059069,
#   ['IL1A', 'TLR2'],
#   0.16165459986901218,
#   0,
#   0],
#  [238,
#   'protein poly-ADP-ribosylation (GO:0070212)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['PARP10'],
#   0.16165459986901218,
#   0,
#   0],
#  [239,
#   'amino sugar metabolic process (GO:0006040)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['GFPT2'],
#   0.16165459986901218,
#   0,
#   0],
#  [240,
#   'aromatic amino acid family metabolic process (GO:0009072)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['KYNU'],
#   0.16165459986901218,
#   0,
#   0],
#  [241,
#   'regulation of cell-cell adhesion mediated by integrin (GO:0033632)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['CCL5'],
#   0.16165459986901218,
#   0,
#   0],
#  [242,
#   'negative regulation of lymphocyte apoptotic process (GO:0070229)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['CCL5'],
#   0.16165459986901218,
#   0,
#   0],
#  [243,
#   'negative regulation of transcription from RNA polymerase II promoter in response to stress (GO:0097201)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['JUN'],
#   0.16165459986901218,
#   0,
#   0],
#  [244,
#   'neuron remodeling (GO:0016322)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['CX3CL1'],
#   0.16165459986901218,
#   0,
#   0],
#  [245,
#   'cytoplasmic pattern recognition receptor signaling pathway in response to virus (GO:0039528)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['IRF7'],
#   0.16165459986901218,
#   0,
#   0],
#  [246,
#   'dicarboxylic acid biosynthetic process (GO:0043650)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['KYNU'],
#   0.16165459986901218,
#   0,
#   0],
#  [247,
#   'regulation of organ growth (GO:0046620)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['SLC6A4'],
#   0.16165459986901218,
#   0,
#   0],
#  [248,
#   'fructose 6-phosphate metabolic process (GO:0006002)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['GFPT2'],
#   0.16165459986901218,
#   0,
#   0],
#  [249,
#   'renal filtration (GO:0097205)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['MCAM'],
#   0.16165459986901218,
#   0,
#   0],
#  [250,
#   'granulocyte activation (GO:0036230)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['CCL5'],
#   0.16165459986901218,
#   0,
#   0],
#  [251,
#   'I-kappaB phosphorylation (GO:0007252)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['TLR2'],
#   0.16165459986901218,
#   0,
#   0],
#  [252,
#   'indolalkylamine catabolic process (GO:0046218)',
#   0.04602821692612118,
#   23.77180406212664,
#   73.18151447362185,
#   ['KYNU'],
#   0.16165459986901218,
#   0,
#   0],
#  [253,
# ...
#   0.48934874753850677,
#   0,
#   0],
#  [808,
#   'positive regulation of epithelial cell proliferation (GO:0050679)',
#   0.4407957502910964,
#   1.7436982196368764,
#   1.4283916561603158,
#   ['PPP1R16B'],
#   0.48934874753850677,
#   0,
#   0],
#  [809,
#   'cellular response to oxidative stress (GO:0034599)',
#   0.4460724133722961,
#   1.7154006243496358,
#   1.384798286431403,
#   ['JUN'],
#   0.49398389480857974,
#   0,
#   0],
#  [810,
#   'regulation of phosphorylation (GO:0042325)',
#   0.4460724133722961,
#   1.7154006243496358,
#   1.384798286431403,
#   ['CCL5'],
#   0.49398389480857974,
#   0,
#   0],
#  [811,
#   'negative regulation of gene expression (GO:0010629)',
#   0.4484299433554305,
#   1.3305706521739131,
#   1.0671214043289576,
#   ['PARP10', 'STC2'],
#   0.49505158758233153,
#   0,
#   0],
#  [812,
#   'negative regulation of growth (GO:0045926)',
#   0.44869224158799953,
#   1.7015913978494623,
#   1.3636860719007413,
#   ['MT2A'],
#   0.49505158758233153,
#   0,
#   0],
#  [813,
#   'synapse organization (GO:0050808)',
#   0.44869224158799953,
#   1.7015913978494623,
#   1.3636860719007413,
#   ['CX3CL1'],
#   0.49505158758233153,
#   0,
#   0],
#  [814,
#   'plasma membrane bounded cell projection organization (GO:0120036)',
#   0.45389517642532135,
#   1.6746253492506984,
#   1.3227681366845945,
#   ['NRTN'],
#   0.5001768713188123,
#   0,
#   0],
#  [815,
#   'cellular response to insulin stimulus (GO:0032869)',
#   0.45647839632867754,
#   1.6614583333333333,
#   1.3029387269935697,
#   ['PCK2'],
#   0.5017905900818919,
#   0,
#   0],
#  [816,
#   'muscle contraction (GO:0006936)',
#   0.45647839632867754,
#   1.6614583333333333,
#   1.3029387269935697,
#   ['HCN4'],
#   0.5017905900818919,
#   0,
#   0],
#  [817,
#   'Golgi organization (GO:0007030)',
#   0.4590495262603869,
#   1.6484954571976327,
#   1.2835139049737554,
#   ['FHDC1'],
#   0.5033831602146297,
#   0,
#   0],
#  [818,
#   'protein glycosylation (GO:0006486)',
#   0.4590495262603869,
#   1.6484954571976327,
#   1.2835139049737554,
#   ['GFPT2'],
#   0.5033831602146297,
#   0,
#   0],
#  [819,
#   'regulation of cell motility (GO:2000145)',
#   0.46669093472805845,
#   1.6107852720755946,
#   1.2275602076257284,
#   ['HBEGF'],
#   0.5105143517695957,
#   0,
#   0],
#  [820,
#   'transmembrane receptor protein serine/threonine kinase signaling pathway (GO:0007178)',
#   0.46669093472805845,
#   1.6107852720755946,
#   1.2275602076257284,
#   ['JUN'],
#   0.5105143517695957,
#   0,
#   0],
#  [821,
#   'positive regulation of peptidyl-tyrosine phosphorylation (GO:0050731)',
#   0.46921426205352185,
#   1.5985932573368906,
#   1.2096487495928274,
#   ['CCL5'],
#   0.5126494434372827,
#   0,
#   0],
#  [822,
#   'negative regulation of inflammatory response to antigenic stimulus (GO:0002862)',
#   0.4742255335075623,
#   1.5747510951812027,
#   1.1748781106619628,
#   ['ADORA2A'],
#   0.5168654964231876,
#   0,
#   0],
#  [823,
#   'organic substance transport (GO:0071702)',
#   0.4742255335075623,
#   1.5747510951812027,
#   1.1748781106619628,
#   ['SLC6A4'],
#   0.5168654964231876,
#   0,
#   0],
#  [824,
#   'negative regulation of cellular macromolecule biosynthetic process (GO:2000113)',
#   0.4765670297282597,
#   1.1733597285067874,
#   0.8696319192519986,
#   ['JUN', 'FOXD1', 'IFI16'],
#   0.5183176816346182,
#   0,
#   0],
#  [825,
#   'regulation of inflammatory response to antigenic stimulus (GO:0002861)',
#   0.4767135867876924,
#   1.5630929791271346,
#   1.1580008889040445,
#   ['ADORA2A'],
#   0.5183176816346182,
#   0,
#   0],
#  [826,
#   'potassium ion transmembrane transport (GO:0071805)',
#   0.48165479960454133,
#   1.5402836216300453,
#   1.1252197049860213,
#   ['HCN4'],
#   0.5230561201516629,
#   0,
#   0],
#  [827,
#   'post-translational protein modification (GO:0043687)',
#   0.4841781784449415,
#   1.239890987450881,
#   0.8992957883304029,
#   ['IGFBP1', 'STC2'],
#   0.5251606119287938,
#   0,
#   0],
#  [828,
#   'regulation of small GTPase mediated signal transduction (GO:0051056)',
#   0.4865498458007512,
#   1.5181259600614438,
#   1.0936821172345188,
#   ['ARHGEF4'],
#   0.5270956662841472,
#   0,
#   0],
#  [829,
#   'Ras protein signal transduction (GO:0007265)',
#   0.48898018996960635,
#   1.5072828490810646,
#   1.0783603452195967,
#   ['JUN'],
#   0.5278862749195216,
#   0,
#   0],
#  [830,
#   'protein localization to organelle (GO:0033365)',
#   0.48898018996960635,
#   1.5072828490810646,
#   1.0783603452195967,
#   ['GBP2'],
#   0.5278862749195216,
#   0,
#   0],
#  [831,
#   'receptor-mediated endocytosis (GO:0006898)',
#   0.4913991522383506,
#   1.4965924579736483,
#   1.0633267624911829,
#   ['SAA1'],
#   0.5278862749195216,
#   0,
#   0],
#  [832,
#   'negative regulation of DNA-binding transcription factor activity (GO:0043433)',
#   0.4913991522383506,
#   1.4965924579736483,
#   1.0633267624911829,
#   ['PARP10'],
#   0.5278862749195216,
#   0,
#   0],
#  [833,
#   'neuron development (GO:0048666)',
#   0.4913991522383506,
#   1.4965924579736483,
#   1.0633267624911829,
#   ['NRTN'],
#   0.5278862749195216,
#   0,
#   0],
#  [834,
#   'nitrogen compound transport (GO:0071705)',
#   0.4913991522383506,
#   1.4965924579736483,
#   1.0633267624911829,
#   ['SLC6A4'],
#   0.5278862749195216,
#   0,
#   0],
#  [835,
#   'monocarboxylic acid metabolic process (GO:0032787)',
#   0.4913991522383506,
#   1.4965924579736483,
#   1.0633267624911829,
#   ['KYNU'],
#   0.5278862749195216,
#   0,
#   0],
#  [836,
#   'supramolecular fiber organization (GO:0097435)',
#   0.49327119346404574,
#   1.2182010713840787,
#   0.860898029025125,
#   ['SAA1', 'UBE2L6'],
#   0.529263469542164,
#   0,
#   0],
#  [837,
#   'brain development (GO:0007420)',
#   0.5080175934086562,
#   1.4257775853359314,
#   0.9655924702858366,
#   ['SLC6A4'],
#   0.5444346251942229,
#   0,
#   0],
#  [838,
#   'positive regulation of Wnt signaling pathway (GO:0030177)',
#   0.5149742516646719,
#   1.3974250141482738,
#   0.927384867440544,
#   ['TLR2'],
#   0.5512313887150486,
#   0,
#   0],
#  [839,
#   'positive regulation of protein kinase activity (GO:0045860)',
#   0.5172714405902054,
#   1.388221238316115,
#   0.9150981043281485,
#   ['CCL5'],
#   0.553030372120875,
#   0,
#   0],
#  [840,
#   'cellular response to starvation (GO:0009267)',
#   0.5263530458751823,
#   1.3525785905074994,
#   0.8680620828584756,
#   ['IFI16'],
#   0.561401524554148,
#   0,
#   0],
#  [841,
#   'T cell receptor signaling pathway (GO:0050852)',
#   0.5263530458751823,
#   1.3525785905074994,
#   0.8680620828584756,
#   ['THEMIS2'],
#   0.561401524554148,
#   0,
#   0],
#  [842,
#   'peptide biosynthetic process (GO:0043043)',
#   0.5352655814613116,
#   1.3187070059440327,
#   0.8241816472793192,
#   ['RPL36A'],
#   0.5695530564303637,
#   0,
#   0],
#  [843,
#   'rRNA metabolic process (GO:0016072)',
#   0.5352655814613116,
#   1.3187070059440327,
#   0.8241816472793192,
#   ['RPL36A'],
#   0.5695530564303637,
#   0,
#   0],
#  [844,
#   'negative regulation of programmed cell death (GO:0043069)',
#   0.5372103172586166,
#   1.1200527704485488,
#   0.6959622717080048,
#   ['CX3CL1', 'IFIT3'],
#   0.5709450883660889,
#   0,
#   0],
#  [845,
#   'negative regulation of canonical Wnt signaling pathway (GO:0090090)',
#   0.5418409067477014,
#   1.2943876212955678,
#   0.7931785363803898,
#   ['IGFBP1'],
#   0.573826792624189,
#   0,
#   0],
#  [846,
#   'adenylate cyclase-modulating G protein-coupled receptor signaling pathway (GO:0007188)',
#   0.5418409067477014,
#   1.2943876212955678,
#   0.7931785363803898,
#   ['ADORA2A'],
#   0.573826792624189,
#   0,
#   0],
#  [847,
#   'regulation of neuron projection development (GO:0010975)',
#   0.5418409067477014,
#   1.2943876212955678,
#   0.7931785363803898,
#   ['CX3CL1'],
#   0.573826792624189,
#   0,
#   0],
#  [848,
#   'regulation of MAPK cascade (GO:0043408)',
#   0.5440121615938746,
#   1.286477680026067,
#   0.7831866117878795,
#   ['CX3CL1'],
#   0.5754468265916338,
#   0,
#   0],
#  [849,
#   'nuclear-transcribed mRNA catabolic process (GO:0000956)',
#   0.5547166646644444,
#   1.2483238456672991,
#   0.7356345080611539,
#   ['RPL36A'],
#   0.5853892331811842,
#   0,
#   0],
#  [850,
#   'positive regulation of I-kappaB kinase/NF-kappaB signaling (GO:0043123)',
#   0.5547166646644444,
#   1.2483238456672991,
#   0.7356345080611539,
#   ['CX3CL1'],
#   0.5853892331811842,
#   0,
#   0],
#  [851,
#   'rRNA processing (GO:0006364)',
#   0.5589285117392199,
#   1.2336834208552139,
#   0.7176752210199345,
#   ['RPL36A'],
#   0.5891408637251235,
#   0,
#   0],
#  [852,
#   'cation transport (GO:0006812)',
#   0.5610196301714814,
#   1.2264901485486979,
#   0.7089105487225444,
#   ['HCN4'],
#   0.590650948666454,
#   0,
#   0],
#  [853,
#   'mitochondrion organization (GO:0007005)',
#   0.5631009394771997,
#   1.2193795575330615,
#   0.7002852636897744,
#   ['IFIT2'],
#   0.592059133450049,
#   0,
#   0],
#  [854,
#   'phosphorylation (GO:0016310)',
#   0.5636772574875606,
#   1.0655451168887917,
#   0.6108487037359085,
#   ['CCL2', 'DCLK1'],
#   0.592059133450049,
#   0,
#   0],
#  [855,
#   'positive regulation of developmental process (GO:0051094)',
#   0.5672343129241839,
#   1.2054007820136852,
#   0.6834415229378875,
#   ['FOXD1'],
#   0.5950984546116876,
#   0,
#   0],
#  [856,
#   'protein stabilization (GO:0050821)',
#   0.5713289936848839,
#   1.1917361362812613,
#   0.6671220482050944,
#   ['STX12'],
#   0.5986940506253983,
#   0,
#   0],
#  [857,
#   'positive regulation of cellular biosynthetic process (GO:0031328)',
#   0.5733619364271537,
#   1.185018321619511,
#   0.6591523514975058,
#   ['CCL5'],
#   0.6001232870188529,
#   0,
#   0],
#  [858,
#   'antigen receptor-mediated signaling pathway (GO:0050851)',
#   0.5833844469790498,
#   1.152524544179523,
#   0.6211057126348188,
#   ['THEMIS2'],
#   0.6099019218417339,
#   0,
#   0],
#  [859,
#   'organelle assembly (GO:0070925)',
#   0.5968491465161645,
#   1.001284818583616,
#   0.5167539665804248,
#   ['STX12', 'FHDC1'],
#   0.622240512960439,
#   0,
#   0],
#  [860,
#   'ribosome biogenesis (GO:0042254)',
#   0.5970257237871581,
#   1.1098913471823453,
#   0.5724764940992287,
#   ['RPL36A'],
#   0.622240512960439,
#   0,
#   0],
#  [861,
#   'regulation of transcription by RNA polymerase II (GO:0006357)',
#   0.5972676495640334,
#   0.9600789313904068,
#   0.49481502460050514,
#   ['JUN',
#    'FOXD1',
#    'ZBTB25',
#    'IFI16',
#    'IRF7',
#    'ZNF239',
#    'FHL5',
#    'CX3CL1',
#    'TLR2',
#    'IRF2BPL'],
#   0.622240512960439,
#   0,
#   0],
#  [862,
#   'negative regulation of intracellular signal transduction (GO:1902532)',
#   0.6083658592709782,
#   1.0757600567654604,
#   0.5346299805772539,
#   ['NMI'],
#   0.6330674892877812,
#   0,
#   0],
#  [863,
#   'regulation of intracellular signal transduction (GO:1902531)',
#   0.6120986074797473,
#   0.9730634682658671,
#   0.4776397693434244,
#   ['PPP1R16B', 'ARHGEF4'],
#   0.6362137322240247,
#   0,
#   0],
#  [864,
#   'modification-dependent protein catabolic process (GO:0019941)',
#   0.6139169430315261,
#   1.059462365591398,
#   0.5169070603564077,
#   ['UBE2L6'],
#   0.6366283212708427,
#   0,
#   0],
#  [865,
#   'ncRNA processing (GO:0034470)',
#   0.6139169430315261,
#   1.059462365591398,
#   0.5169070603564077,
#   ['RPL36A'],
#   0.6366283212708427,
#   0,
#   0],
#  [866,
#   'phosphate-containing compound metabolic process (GO:0006796)',
#   0.6336129765990864,
#   1.0036691637364317,
#   0.457991259582563,
#   ['GFPT2'],
#   0.6562942725281531,
#   0,
#   0],
#  [867,
#   'negative regulation of multicellular organismal process (GO:0051241)',
#   0.637085719846623,
#   0.9941440759250846,
#   0.44821091481305636,
#   ['SLC6A4'],
#   0.6583708418230654,
#   0,
#   0],
#  [868,
#   'translation (GO:0006412)',
#   0.637085719846623,
#   0.9941440759250846,
#   0.44821091481305636,
#   ['RPL36A'],
#   0.6583708418230654,
#   0,
#   0],
#  [869,
#   'extracellular structure organization (GO:0043062)',
#   0.6405258939677524,
#   0.9847961990497625,
#   0.43869295842203554,
#   ['ICAM1'],
#   0.6611642426801771,
#   0,
#   0],
#  [870,
#   'external encapsulating structure organization (GO:0045229)',
#   0.6422338620760967,
#   0.9801871764237355,
#   0.4340295973057075,
#   ['ICAM1'],
#   0.6621652577956997,
#   0,
#   0],
#  [871,
#   'transcription, DNA-templated (GO:0006351)',
#   0.6489858155701543,
#   0.9621700879765396,
#   0.4159888670313223,
#   ['HSF2BP'],
#   0.6683585264826963,
#   0,
#   0],
#  [872,
#   'regulation of I-kappaB kinase/NF-kappaB signaling (GO:0043122)',
#   0.6539669014612337,
#   0.9490814407637784,
#   0.4030735005176567,
#   ['CX3CL1'],
#   0.672715952535237,
#   0,
#   0],
#  [873,
#   'cilium organization (GO:0044782)',
#   0.6604997168328015,
#   0.9321680640424423,
#   0.3866247060464274,
#   ['FHDC1'],
#   0.6786577846495108,
#   0,
#   0],
#  [874,
#   'regulation of autophagy (GO:0010506)',
#   0.6653191108535186,
#   0.9198690977092099,
#   0.37483606730510444,
#   ['IFI16'],
#   0.6828275085075586,
#   0,
#   0],
#  [875,
#   'membrane organization (GO:0061024)',
#   0.682418153033612,
#   0.877392584660688,
#   0.3352628331733753,
#   ['HBEGF'],
#   0.6995760951670285,
#   0,
#   0],
#  [876,
#   'positive regulation of nucleic acid-templated transcription (GO:1903508)',
#   0.6965795426176677,
#   0.828435978474417,
#   0.2995403214259702,
#   ['JUN', 'IRF7'],
#   0.7132783672694611,
#   0,
#   0],
#  [877,
#   'regulation of canonical Wnt signaling pathway (GO:0060828)',
#   0.6986524120092831,
#   0.8386243386243386,
#   0.30073230224620795,
#   ['IGFBP1'],
#   0.7137713138636981,
#   0,
#   0],
#  [878,
#   'positive regulation of phosphorylation (GO:0042327)',
#   0.6986524120092831,
#   0.8386243386243386,
#   0.30073230224620795,
#   ['CCL5'],
#   0.7137713138636981,
#   0,
#   0],
#  [879,
#   'positive regulation of cell differentiation (GO:0045597)',
#   0.7057575309544657,
#   0.8220994937450316,
#   0.28648814267775824,
#   ['IFITM1'],
#   0.7202099036019974,
#   0,
#   0],
#  [880,
#   'protein ubiquitination (GO:0016567)',
#   0.7107603960931563,
#   0.8056779449663314,
#   0.27507448471124046,
#   ['HERC5', 'UBE2L6'],
#   0.7244909946540469,
#   0,
#   0],
#  [881,
#   'regulation of protein phosphorylation (GO:0001932)',
#   0.7167824869768546,
#   0.7969567863664029,
#   0.26537294193225086,
#   ['BMPER'],
#   0.7298001030854013,
#   0,
#   0],
#  [882,
#   'regulation of cell cycle (GO:0051726)',
#   0.7546051909206433,
#   0.7148168398031711,
#   0.20126425290070094,
#   ['JUN'],
#   0.7674386125349398,
#   0,
#   0],
#  [883,
#   'extracellular matrix organization (GO:0030198)',
#   0.7592548381757995,
#   0.7051102240443053,
#   0.19419990861506237,
#   ['ICAM1'],
#   0.7712928537301158,
#   0,
#   0],
#  [884,
#   'chemical synaptic transmission (GO:0007268)',
#   0.7660663515946587,
#   0.6910276749515247,
#   0.1841495410502552,
#   ['GRID1'],
#   0.7773320332357566,
#   0,
#   0],
#  [885,
#   'cellular macromolecule biosynthetic process (GO:0034645)',
#   0.7748525957984838,
#   0.6730907966608265,
#   0.17169366071764278,
#   ['RPL36A'],
#   0.7844726618862753,
#   0,
#   0],
#  [886,
#   'cilium assembly (GO:0060271)',
#   0.7748525957984838,
#   0.6730907966608265,
#   0.17169366071764278,
#   ['FHDC1'],
#   0.7844726618862753,
#   0,
#   0],
#  [887,
#   'transcription by RNA polymerase II (GO:0006366)',
#   0.7812272678962782,
#   0.660228536758014,
#   0.16300327904717365,
#   ['HSF2BP'],
#   0.7900347906459544,
#   0,
#   0],
#  [888,
#   'cellular protein localization (GO:0034613)',
#   0.7904559098952111,
#   0.6418174665617624,
#   0.15092042416145118,
#   ['STX12'],
#   0.7984672873603652,
#   0,
#   0],
#  [889,
#   'intracellular protein transport (GO:0006886)',
#   0.7973665130842648,
#   0.6281816722837426,
#   0.14224598557314297,
#   ['STX12'],
#   0.8045419147768116,
#   0,
#   0],
#  [890,
#   'cellular response to DNA damage stimulus (GO:0006974)',
#   0.8105183151507495,
#   0.6025510675663185,
#   0.12658473612267165,
#   ['IRF7'],
#   0.8168931783036205,
#   0,
#   0],
#  [891,
#   'ubiquitin-dependent protein catabolic process (GO:0006511)',
#   0.8141183293587055,
#   0.5956014499375553,
#   0.12248517360273081,
#   ['UBE2L6'],
#   0.8196006076708854,
#   0,
#   0],
#  [892,
#   'gene expression (GO:0010467)',
#   0.8158928755273476,
#   0.5921853702862335,
#   0.12049326757747801,
#   ['RPL36A'],
#   0.8204662660852363,
#   0,
#   0],
#  [893,
#   'protein transport (GO:0015031)',
#   0.8270257648139828,
#   0.57088592800374,
#   0.10842232998004626,
#   ['STX12'],
#   0.830730247523116,
#   0,
#   0],
#  [894,
#   'positive regulation of protein phosphorylation (GO:0001934)',
#   0.828678345694389,
#   0.567741935483871,
#   0.10669188238072377,
#   ['CX3CL1'],
#   0.8314591455121555,
#   0,
#   0],
#  [895,
#   'protein modification by small protein conjugation (GO:0032446)',
#   0.8572693253533527,
#   0.5138625342610162,
#   0.07913644609923648,
#   ['HERC5'],
#   0.8591850109966005,
#   0,
#   0],
#  [896,
#   'organelle organization (GO:0006996)',
#   0.8646261488974768,
#   0.5000898195909359,
#   0.07274209662425941,
#   ['CCL2'],
#   0.865591133438657,
#   0,
#   0],
#  [897,
#   'regulation of transcription, DNA-templated (GO:0006355)',
#   0.9143447108858688,
#   0.6355134904608492,
#   0.05690872896291105,
#   ['JUN', 'FOXD1', 'ZBTB25', 'IFI16', 'IRF7', 'ZNF239', 'IRF2BPL'],
#   0.9143447108858688,
#   0,
#   0]]

# %%
import json

with open('results_xGBoost.json', 'w') as file:
     file.write(json.dumps(results)) # use `json.loads` to do the reverse

# %%
import json

with open('results_xGBoost.json') as file:
    results = json.load(file)

# %%
dataset = {'p-value': [], 'Score': []}
index = []

for term in results:
    index += [term[1]]
    dataset['p-value'] += [term[6]]
    dataset['Score'] += [term[4]]
enrichment_dataset = pd.DataFrame(dataset, index = index)

# %%
len(enrichment_dataset[enrichment_dataset['p-value'] < 0.001].index)
# Out:
# 15

# %%
pd.set_option("display.max_rows", None)
selection = enrichment_dataset[enrichment_dataset['p-value'] < 0.01].sort_values('Score', ascending = False).head(25)

selection['p-value'] = selection['p-value'].map(lambda x: '%.2E' % x)
selection['Score'] = selection['Score'].map(lambda x: '%.2f' % x)

#selection.to_csv('xGBoost_table.csv')
selection

# %% [markdown]
# ### Two class comparison

# %% [markdown]
# ##### NHBE

# %%
cols_nhbe_healthy = dt.get_columns('NHBE', 'healthy')
cols_nhbe_cov2 = dt.get_columns('NHBE', 'sars-cov2')

labels_nhbe = [0] * len(cols_nhbe_healthy) + [1] * len(cols_nhbe_cov2)

data_nhbe = dt.get_data('NHBE', 'healthy', 'sars-cov2')

filtered_data_NHBE = dt.get_p_values('mannwhitneyu', data_nhbe, cols_nhbe_healthy, cols_nhbe_cov2)
filtered_data_NHBE.drop(['p-value'], axis = 1, inplace = True)

len(filtered_data_NHBE.index)

# %%
parameters = {
    'seed': 42, 
    'use_label_encoder': False,
    'booster': 'gbtree',
    'eta': 0.3,
    'gamma': 0,
    'alpha': 0,
    'n_estimators': 200,
    'eval_metric': 'mlogloss',
}

stats_NHBE = dt.apply_loocv(filtered_data_NHBE.T.values, np.array(labels_nhbe), xgb.XGBClassifier(**parameters))
stats_NHBE

# %%
nhbe_clf = xgb.XGBClassifier(**parameters).fit(filtered_data_NHBE.T, labels_nhbe)

list(sorted(zip(nhbe_clf.feature_importances_, filtered_data_NHBE.T.columns), reverse = True))

# %%
selected_genes_nhbe = [x[1] for x in list(sorted(zip(nhbe_clf.feature_importances_, filtered_data_NHBE.T.columns), reverse = True)) if x[0] > 0]
selected_genes_nhbe

# %%
results_nhbe = ea.getEnrichment(selected_genes_nhbe, 'GO_Biological_Process_2021')['GO_Biological_Process_2021']
results_nhbe

# %%
import json

with open('results_xGBoost_NHBE.json', 'w') as file:
     #file.write(json.dumps(results_nhbe)) # use `json.loads` to do the reverse

# %%
import json

with open('results_xGBoost_NHBE.json') as file:
    results_nhbe = json.load(file)

# %%
dataset = {'p-value': [], 'Score': [], 'Value': []}
index_nhbe = []

cols_nhbe_healthy = dt.get_columns('NHBE', 'healthy')
cols_nhbe_cov2 = dt.get_columns('NHBE', 'sars-cov2')

data_nhbe = dt.get_data('NHBE', 'healthy', 'sars-cov2')

for term in results_nhbe:
    index_nhbe += [term[1]]
    dataset['p-value'] += [term[6]]
    dataset['Score'] += [term[4]]
    
    genes = term[5]
    avg_sub = np.mean(data_nhbe.loc[genes, cols_nhbe_healthy].values, axis = 1) - np.mean(data_nhbe.loc[genes, cols_nhbe_cov2].values, axis = 1)

    downs = 0
    ups = 0

    for e in avg_sub:
        if e > 0:
            downs += 1
        elif e < 0:
            ups += 1

    dataset['Value'] += ['%d up, %d down' % (ups, downs)]
    
enrichment_nhbe_dataset = pd.DataFrame(dataset, index = index_nhbe)

# %%
len(enrichment_nhbe_dataset[enrichment_nhbe_dataset['p-value'] < 0.01].index)
# Out:
# 0

# %%
pd.set_option("display.max_rows", None)
selection = enrichment_nhbe_dataset[enrichment_nhbe_dataset['p-value'] < 0.05].sort_values('Score', ascending = False)#.head(25)[['p-value', 'Score']]

selection['p-value'] = selection['p-value'].map(lambda x: '%.2E' % x)
selection['Score'] = selection['Score'].map(lambda x: '%.2f' % x)

#selection.to_csv('NHBE_xGBoost_table.csv')
selection

# %% [markdown]
# ##### A549

# %%
cols_healthy_A549 = dt.get_columns('A549', 'healthy')
cols_cov2_A549 = dt.get_columns('A549', 'sars-cov2')

labels_a549 = [0] * len(cols_healthy_A549) + [1] * len(cols_cov2_A549)

data_a549 = dt.get_data('A549', 'healthy', 'sars-cov2')

filtered_data_a549 = dt.get_p_values('mannwhitneyu', data_a549, cols_healthy_A549, cols_cov2_A549, limit = 0.01)
filtered_data_a549.drop(['p-value'], axis = 1, inplace = True)

len(filtered_data_a549)

# %%
parameters = {
    'seed': 42, 
    'use_label_encoder': False,
    'booster': 'gbtree',
    'learning_rate': 0.3,
    'gamma': 0,
    'alpha': 0,
    'n_estimators': 300,
    'eval_metric': 'mlogloss',
}

stats_a549 = dt.apply_loocv(filtered_data_a549.T.values, np.array(labels_a549), xgb.XGBClassifier(**parameters))
stats_a549

# %%
a549_clf = xgb.XGBClassifier(**parameters).fit(filtered_data_a549.T, labels_a549)

list(sorted(zip(a549_clf.feature_importances_, filtered_data_a549.T.columns), reverse = True))

# %%
selected_genes_a549 = [x[1] for x in list(sorted(zip(a549_clf.feature_importances_, filtered_data_a549.T.columns), reverse = True)) if x[0] > 0]
selected_genes_a549

# %%
results_a549 = ea.getEnrichment(selected_genes_a549, 'GO_Biological_Process_2021')['GO_Biological_Process_2021']
results_a549

# %%
import json

with open('results_xGBoost_A549.json', 'w') as file:
     #file.write(json.dumps(results_a549)) # use `json.loads` to do the reverse

# %%
import json

with open('results_xGBoost_A549.json') as file:
    results_a549 = json.load(file)

# %%
dataset = {'p-value': [], 'Score': [], 'Value': []}
index_a549 = []

cols_healthy_A549 = dt.get_columns('A549', 'healthy')
cols_cov2_A549 = dt.get_columns('A549', 'sars-cov2')

data_a549 = dt.get_data('A549', 'healthy', 'sars-cov2')

for term in results_a549:
    index_a549 += [term[1]]
    dataset['p-value'] += [term[6]]
    dataset['Score'] += [term[4]]
    
    genes = term[5]
    avg_sub = np.mean(data_a549.loc[genes, cols_healthy_A549].values, axis = 1) - np.mean(data_a549.loc[genes, cols_cov2_A549].values, axis = 1)

    downs = 0
    ups = 0

    for e in avg_sub:
        if e > 0:
            downs += 1
        elif e < 0:
            ups += 1

    dataset['Value'] += ['%d up, %d down' % (ups, downs)]
enrichment_a549_dataset = pd.DataFrame(dataset, index = index_a549)

# %%
len(enrichment_a549_dataset[enrichment_a549_dataset['p-value'] < 0.01].index)

# %%
pd.set_option("display.max_rows", None)
selection = enrichment_a549_dataset[enrichment_a549_dataset['p-value'] < 0.05].sort_values('Score', ascending = False).head(25)[['p-value', 'Score']]

selection['p-value'] = selection['p-value'].map(lambda x: '%.2E' % x)
selection['Score'] = selection['Score'].map(lambda x: '%.2f' % x)

#selection.to_csv('A549_xGBoost_table.csv')
selection

# %% [markdown]
# ##### Calu3

# %%
cols_healthy_Calu3 = dt.get_columns('Calu3', 'healthy')
cols_cov2_Calu3 = dt.get_columns('Calu3', 'sars-cov2')

labels_calu3 = [0] * len(cols_healthy_Calu3) + [1] * len(cols_cov2_Calu3)

data_calu3 = dt.get_data('Calu3', 'healthy', 'sars-cov2')

filtered_data_calu3 = dt.get_p_values('mannwhitneyu', data_calu3, cols_healthy_Calu3, cols_cov2_Calu3)
filtered_data_calu3.drop(['p-value'], axis = 1, inplace = True)

len(filtered_data_calu3.index)

# %%
parameters = {
    'seed': 42, 
    'use_label_encoder': False,
    'booster': 'gbtree',
    'learning_rate': 0.3,
    'gamma': 0,
    'alpha': 0,
    'n_estimators': 100,
    'eval_metric': 'mlogloss',
}

stats_calu3 = dt.apply_loocv(filtered_data_calu3.T.values, np.array(labels_calu3), xgb.XGBClassifier(**parameters))
stats_calu3

# %%
calu3_clf = xgb.XGBClassifier(**parameters).fit(filtered_data_calu3.T, labels_calu3)

list(sorted(zip(calu3_clf.feature_importances_, filtered_data_calu3.T.columns), reverse = True))

# %%
xgb.XGBClassifier()

# %%
selected_genes_a549 = [x[1] for x in list(sorted(zip(a549_clf.feature_importances_, filtered_data_a549.T.columns), reverse = True)) if x[0] > 0]
selected_genes_a549

# %%
results_calu3 = ea.getEnrichment(calu3_features[:92], 'GO_Biological_Process_2021')['GO_Biological_Process_2021']
results_calu3

# %%
import json

with open('results_xGBoost_Calu3.json', 'w') as file:
     file.write(json.dumps(results_calu3)) # use `json.loads` to do the reverse

# %%
import json

with open('results_xGBoost_Calu3.json') as file:
    results_calu3 = json.load(file)

# %%
dataset = {'p-value': [], 'Score': [], 'Value': []}
index_calu3 = []

cols_healthy_Calu3 = dt.get_columns('Calu3', 'healthy')
cols_cov2_Calu3 = dt.get_columns('Calu3', 'sars-cov2')

data_calu3 = dt.get_data('Calu3', 'healthy', 'sars-cov2')

for term in results_calu3:
    index_calu3 += [term[1]]
    dataset['p-value'] += [term[6]]
    dataset['Score'] += [term[4]]
    
    genes = term[5]
    avg_sub = np.mean(data_calu3.loc[genes, cols_healthy_Calu3].values, axis = 1) - np.mean(data_calu3.loc[genes, cols_cov2_Calu3].values, axis = 1)

    downs = 0
    ups = 0

    for e in avg_sub:
        if e > 0:
            downs += 1
        elif e < 0:
            ups += 1

    dataset['Value'] += ['%d up, %d down' % (ups, downs)]
    
enrichment_calu3_dataset = pd.DataFrame(dataset, index = index_calu3)

# %%
pd.set_option("display.max_rows", None)
selection = enrichment_calu3_dataset[enrichment_calu3_dataset['p-value'] < 0.05].sort_values('Score', ascending = False).head(25)[['p-value', 'Score']]

selection['p-value'] = selection['p-value'].map(lambda x: '%.2E' % x)
selection['Score'] = selection['Score'].map(lambda x: '%.2f' % x)

#selection.to_csv('Calu3_xGBoost_table.csv')
selection
